# %% [markdown]
# <a href="https://colab.research.google.com/github/Ana1890/MRIimages_deeplearning/blob/main/3-earlystopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Estadificación de Alzheimer por medio de imágenes MRI utilizando redes neuronales
#
# Dataset provisto por el sitio web de Kaggle: https://www.kaggle.com/tourist55/Alzheimers-dataset-4-class-of-images
#
# Se intentará ver cuál es el número de épocas en el que la función de loss tiene su mínimo para poder entrenar con el número de épocas adecuado evitando overfitting o underfitting

# %%
# !pip install progress
# Out:
# Collecting progress
#   Downloading https://files.pythonhosted.org/packages/38/ef/2e887b3d2b248916fc2121889ce68af8a16aaddbe82f9ae6533c24ff0d2b/progress-1.5.tar.gz
# Building wheels for collected packages: progress
#   Building wheel for progress (setup.py) ... done
#   Created wheel for progress: filename=progress-1.5-cp37-none-any.whl size=8088 sha256=671a8ff66d768405822b62d289f537f586c0354b3d2c01ded443be5f5cf71796
#   Stored in directory: /root/.cache/pip/wheels/6c/c8/80/32a294e3041f006c661838c05a411c7b7ffc60ff939d14e116
# Successfully built progress
# Installing collected packages: progress
# Successfully installed progress-1.5

# %% [markdown]
# Accedemos a nuestro drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Programa de investigación en IB/Imágenes/Alzheimer_s Dataset')

# %%
# !ls
# Out:
# loss_plot.png  test  train

# %%
# !ls test
# Out:
# MildDemented  ModerateDemented	NonDemented  VeryMildDemented

# %%
# !ls train
# Out:
# MildDemented  ModerateDemented	NonDemented  VeryMildDemented

# %%
# !pip install pytorchtools
# Out:
# Collecting pytorchtools
#   Downloading https://files.pythonhosted.org/packages/07/7d/91fc993eed451ff2aff02e09a8e0246125b72cbc7068cb94242ca2c0e72f/pytorchtools-0.0.2-py2.py3-none-any.whl
# Installing collected packages: pytorchtools
# Successfully installed pytorchtools-0.0.2

# %% [markdown]
# # Importando librerías necesarias

# %%
# Generales
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np
import random

# Data
from sklearn.model_selection import train_test_split

from torch.utils.data import Dataset

# Model
import torch
import torch.nn as nn
from torchvision import datasets, models, transforms
# from pytorchtools import EarlyStopping

# Métricas y visualización
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Cargar datos

# %%
FOLDER_PATH = '/content/drive/MyDrive/Programa de investigación en IB/Imágenes/Alzheimer_s Dataset/train'
categories = sorted(os.listdir(FOLDER_PATH))
num_classes = 4

MILD_INDEX = categories.index("MildDemented")
MODERATE_INDEX = categories.index("ModerateDemented")
NON_INDEX = categories.index("NonDemented")
VERYMILD_INDEX = categories.index("VeryMildDemented")

# Almacenar las rutas a las imagenes agrupados por categorias en memoria
images_path = [list() for category in categories]

for index, category in enumerate(categories):
    category_path = os.path.join(FOLDER_PATH, category)

    # Recorrer imágenes
    images = [i for i in os.listdir(category_path)]
    for image_name in images:
        image_path = os.path.join(category_path, image_name)
        images_path[index].append(image_path)

print("Sobre el dataset")
for category_name, images in zip(categories, images_path):
    print("#Imagenes de la clase {}: {}".format(category_name, len(images)))
# Out:
# Sobre el dataset
# #Imagenes de la clase MildDemented: 717
# #Imagenes de la clase ModerateDemented: 52
# #Imagenes de la clase NonDemented: 2560
# #Imagenes de la clase VeryMildDemented: 1792

# %%
train_data = list()

for class_index, images_per_class in enumerate(images_path):
  train_data.extend([(img, class_index) for img in images_per_class])

train_data1 = np.array(train_data)

# %%
train_data1[:,1]
# Out:
# array(['0', '0', '0', ..., '3', '3', '3'], dtype='<U128')

# %%
# Generamos datos de validación

train_data1, val_data, train_labels1, val_labels = train_test_split(train_data1[:,0], train_data1[:,1].astype(int) , test_size=0.20, random_state=42)

print(train_data1.shape,  val_data.shape, train_labels1.shape, val_labels.shape)
# Out:
# (4096,) (1025,) (4096,) (1025,)

# %%
train_data2 = list()
train_data2.extend([(path, label) for path,label in zip(train_data1, train_labels1)])

# %%
val_data2 = list()
val_data2.extend([(path, label) for path,label in zip(val_data, val_labels)])

# %%
FOLDER_PATH_TEST = '/content/drive/MyDrive/Programa de investigación en IB/Imágenes/Alzheimer_s Dataset/test'
categories_test = sorted(os.listdir(FOLDER_PATH_TEST))
num_classes = 4

MILD_INDEX_TEST = categories_test.index("MildDemented")
MODERATE_INDEX_TEST = categories_test.index("ModerateDemented")
NON_INDEX_TEST = categories_test.index("NonDemented")
VERYMILD_INDEX_TEST = categories_test.index("VeryMildDemented")

# Almacenar las rutas a las imagenes agrupados por categorias en memoria
images_path_test = [list() for category in categories_test]

for index, category in enumerate(categories_test):
    category_path_test = os.path.join(FOLDER_PATH_TEST, category)

    # Recorrer imágenes
    images_test = [i for i in os.listdir(category_path_test)]
    for image_name in images_test:
        image_path_test = os.path.join(category_path_test, image_name)
        images_path_test[index].append(image_path_test)

print("Sobre el dataset")
for category_name, images in zip(categories_test, images_path_test):
    print("#Imagenes de la clase {}: {}".format(category_name, len(images)))
# Out:
# Sobre el dataset
# #Imagenes de la clase MildDemented: 179
# #Imagenes de la clase ModerateDemented: 12
# #Imagenes de la clase NonDemented: 640
# #Imagenes de la clase VeryMildDemented: 448

# %%
test_data = list()

for class_index, images_per_class in enumerate(images_path_test):
  test_data.extend([(img, class_index) for img in images_per_class])

# %% [markdown]
# * Las clases están muy desbalanceadas

# %% [markdown]
# ## Visualización random

# %%
random.seed(0)

def pick_randomly_file(image_list, ammount):
    max_length = len(image_list)
    chosen_images = []
    for _ in range(ammount):
        index = random.randint(0, max_length)
        chosen_images.append(image_list[index])
    
    return chosen_images


sample_images = 5
mild_sample = pick_randomly_file(images_path[MILD_INDEX], sample_images)
moderate_sample = pick_randomly_file(images_path[MODERATE_INDEX], sample_images)
non_sample = pick_randomly_file(images_path[NON_INDEX], sample_images)
Verymild_sample = pick_randomly_file(images_path[VERYMILD_INDEX], sample_images)

# %%
def visualize_sample(image_list, ax, title):
    ax[0].set_ylabel(title)
    for index in range(len(image_list)):        
        ax[index].imshow(cv2.imread(image_list[index]))
        ax[index].set_yticklabels([])
        ax[index].set_xticklabels([])


fx, ax = plt.subplots(num_classes,sample_images, figsize=(20,10))
visualize_sample(mild_sample, ax[0], "Mild")
visualize_sample(moderate_sample, ax[1], "Moderate")
visualize_sample(non_sample, ax[2], "Non")
visualize_sample(Verymild_sample, ax[3], "VeryMild")

plt.show()

# %%
image_s = [mild_sample, moderate_sample, non_sample, Verymild_sample]

for s in image_s:
  for l in s:
    print("El tamaño de la imagen ", s.index(l), "de la clase ", categories[image_s.index(s)], "es: ", (cv2.imread(l).size), "y la dimensión es: ", (cv2.imread(l).shape))
# Out:
# El tamaño de la imagen  0 de la clase  MildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  1 de la clase  MildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  2 de la clase  MildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  3 de la clase  MildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  4 de la clase  MildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  0 de la clase  ModerateDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  1 de la clase  ModerateDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  2 de la clase  ModerateDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  3 de la clase  ModerateDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  4 de la clase  ModerateDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  0 de la clase  NonDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  1 de la clase  NonDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  2 de la clase  NonDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  3 de la clase  NonDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  4 de la clase  NonDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  0 de la clase  VeryMildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  1 de la clase  VeryMildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  2 de la clase  VeryMildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  3 de la clase  VeryMildDemented es:  109824 y la dimensión es:  (208, 176, 3)
# El tamaño de la imagen  4 de la clase  VeryMildDemented es:  109824 y la dimensión es:  (208, 176, 3)

# %% [markdown]
# El conjunto de datos se encuentra desbalanceado, tiene imágenes de una dimensión de 208 x 176 x 3 dimensiones. Se podría pasar a 1 dimensión y de ahí normalizar, o tener 3 dimensiones y normalizarla directamente.

# %% [markdown]
# Pre-procesamiento:
# * Data Augmentation: Mild demented, Moderate demented
# * Normalzación
# * Visualización
# * Reshape, binarización, morfología

# %% [markdown]
# # Clase Dataset

# %%
class MRIDataset(Dataset):

    """MRI dataset."""

    def __init__(self, raw_data, input_size=(224,224)):
        self.raw_data = raw_data
        self.input_size = input_size
        self.images = list()
        self.annotations = list()
        self.transf = transforms.RandomAutocontrast()
        self.count = 0

        for path_to_image, label in self.raw_data:
            image_tensor = self._preprocess(path_to_image)
            target_tensor = torch.tensor(label)

            self.images.append(image_tensor)
            self.annotations.append(target_tensor)

    def _preprocess(self, path_to_image):
        '''
        Función dedicada a convertir nuestra imagen en números.
        Ademas también transforma la imagen en un tensor, que es necesario
        Para poder ser usado en el modelo.
        También se cambia el tamaño de la imagen para que sea uniforme en todas 
        las imágenes.
        '''

        img = cv2.imread(path_to_image)
        img = cv2.resize(img, self.input_size)

        # Aquí podemos plantear pasar la imagen a escala de grises

        # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Aquí normalizamos
        img = img / 255.

        input_tensor = torch.from_numpy(img).reshape(3, self.input_size[0], self.input_size[1]).float()
        self.count += 1
        print("transforme a tensor ", self.count)

        input_tensor = self.transf(input_tensor)
        print("transforme a sharpness")

        return input_tensor

    def __len__(self):
        return len(self.raw_data)

    def __getitem__(self, index):
        sample = {'input': self.images[index], 'target': self.annotations[index]}
        return sample

# %% [markdown]
# # Creamos la red neuronal

# %%
model = models.resnet50(pretrained=True)

# Freezing model

# for param in model.parameters():
#   param.requires_grad = False

new_model = nn.Sequential(
    nn.Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False),
    nn.BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False),
    
    model.layer1,
    model.layer2,
    model.layer3,
    *(list(model.layer4.children())[:-1]),

    nn.Conv2d(2048, 32, kernel_size=(1,1), stride=(1, 1), bias=False),
    nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),
    nn.Dropout(0.4),
    nn.Flatten(),
    nn.Linear(32*7*7,4),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(4,4),
    nn.LogSoftmax(dim=1)

    )
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# HBox(children=(FloatProgress(value=0.0, max=102530333.0), HTML(value='')))

# %% [markdown]
# https://pytorch.org/tutorials/recipes/recipes/defining_a_neural_network.html

# %%
# Capa 4 sin su última sub capa
# newmodel = torch.nn.Sequential(*(list(model.layer4.children())[:-1]))
# print(newmodel)

# %% [markdown]
# https://www.it-swarm-es.com/es/python/como-eliminar-la-ultima-capa-fc-de-un-modelo-resnet-en-pytorch/807243870/

# %% [markdown]
# # Definimos algunos hiperparámetros

# %%
# Hyperparameters
lr = 0.0001              # Learning rate
input_size = (224,224)

# Select the device to use
if torch.cuda.is_available(): device = torch.device('cuda')
else: device = torch.device('cpu')

# Send the model to the device
new_model = new_model.to(device)

# Create dataloader
from torch.utils.data import DataLoader

batch_size = 16

# %%
from torchsummary import summary

summary(new_model, (3,224,224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        Bottleneck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        Bottleneck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        Bottleneck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        Bottleneck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        Bottleneck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        Bottleneck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        Bottleneck-78          [-1, 512, 28, 28]               0
#            Conv2d-79          [-1, 256, 28, 28]         131,072
#       BatchNorm2d-80          [-1, 256, 28, 28]             512
#              ReLU-81          [-1, 256, 28, 28]               0
#            Conv2d-82          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-86         [-1, 1024, 14, 14]           2,048
#            Conv2d-87         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-88         [-1, 1024, 14, 14]           2,048
#              ReLU-89         [-1, 1024, 14, 14]               0
#        Bottleneck-90         [-1, 1024, 14, 14]               0
#            Conv2d-91          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-92          [-1, 256, 14, 14]             512
#              ReLU-93          [-1, 256, 14, 14]               0
#            Conv2d-94          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-95          [-1, 256, 14, 14]             512
#              ReLU-96          [-1, 256, 14, 14]               0
#            Conv2d-97         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-98         [-1, 1024, 14, 14]           2,048
#              ReLU-99         [-1, 1024, 14, 14]               0
#       Bottleneck-100         [-1, 1024, 14, 14]               0
#           Conv2d-101          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-102          [-1, 256, 14, 14]             512
#             ReLU-103          [-1, 256, 14, 14]               0
#           Conv2d-104          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-105          [-1, 256, 14, 14]             512
#             ReLU-106          [-1, 256, 14, 14]               0
#           Conv2d-107         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-108         [-1, 1024, 14, 14]           2,048
#             ReLU-109         [-1, 1024, 14, 14]               0
#       Bottleneck-110         [-1, 1024, 14, 14]               0
#           Conv2d-111          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-112          [-1, 256, 14, 14]             512
#             ReLU-113          [-1, 256, 14, 14]               0
#           Conv2d-114          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-115          [-1, 256, 14, 14]             512
#             ReLU-116          [-1, 256, 14, 14]               0
#           Conv2d-117         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-118         [-1, 1024, 14, 14]           2,048
#             ReLU-119         [-1, 1024, 14, 14]               0
#       Bottleneck-120         [-1, 1024, 14, 14]               0
#           Conv2d-121          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-122          [-1, 256, 14, 14]             512
#             ReLU-123          [-1, 256, 14, 14]               0
#           Conv2d-124          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-125          [-1, 256, 14, 14]             512
#             ReLU-126          [-1, 256, 14, 14]               0
#           Conv2d-127         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-128         [-1, 1024, 14, 14]           2,048
#             ReLU-129         [-1, 1024, 14, 14]               0
#       Bottleneck-130         [-1, 1024, 14, 14]               0
#           Conv2d-131          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-132          [-1, 256, 14, 14]             512
#             ReLU-133          [-1, 256, 14, 14]               0
#           Conv2d-134          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-135          [-1, 256, 14, 14]             512
#             ReLU-136          [-1, 256, 14, 14]               0
#           Conv2d-137         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-138         [-1, 1024, 14, 14]           2,048
#             ReLU-139         [-1, 1024, 14, 14]               0
#       Bottleneck-140         [-1, 1024, 14, 14]               0
#           Conv2d-141          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-142          [-1, 512, 14, 14]           1,024
#             ReLU-143          [-1, 512, 14, 14]               0
#           Conv2d-144            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-148           [-1, 2048, 7, 7]           4,096
#           Conv2d-149           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-150           [-1, 2048, 7, 7]           4,096
#             ReLU-151           [-1, 2048, 7, 7]               0
#       Bottleneck-152           [-1, 2048, 7, 7]               0
#           Conv2d-153            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-154            [-1, 512, 7, 7]           1,024
#             ReLU-155            [-1, 512, 7, 7]               0
#           Conv2d-156            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-157            [-1, 512, 7, 7]           1,024
#             ReLU-158            [-1, 512, 7, 7]               0
#           Conv2d-159           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-160           [-1, 2048, 7, 7]           4,096
#             ReLU-161           [-1, 2048, 7, 7]               0
#       Bottleneck-162           [-1, 2048, 7, 7]               0
#           Conv2d-163             [-1, 32, 7, 7]          65,536
#      BatchNorm2d-164             [-1, 32, 7, 7]              64
#          Dropout-165             [-1, 32, 7, 7]               0
#          Flatten-166                 [-1, 1568]               0
#           Linear-167                    [-1, 4]           6,276
#             ReLU-168                    [-1, 4]               0
#          Dropout-169                    [-1, 4]               0
#           Linear-170                    [-1, 4]              20
#       LogSoftmax-171                    [-1, 4]               0
# ================================================================
# Total params: 19,117,336
# Trainable params: 19,117,336
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 282.37
# Params size (MB): 72.93
# Estimated Total Size (MB): 355.87
# ----------------------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
dataset = MRIDataset(train_data2)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# transforme a tensor  1597
# transforme a sharpness
# transforme a tensor  1598
# transforme a sharpness
# transforme a tensor  1599
# transforme a sharpness
# transforme a tensor  1600
# transforme a sharpness
# transforme a tensor  1601
# transforme a sharpness
# transforme a tensor  1602
# transforme a sharpness
# transforme a tensor  1603
# transforme a sharpness
# transforme a tensor  1604
# transforme a sharpness
# transforme a tensor  1605
# transforme a sharpness
# transforme a tensor  1606
# transforme a sharpness
# transforme a tensor  1607
# transforme a sharpness
# transforme a tensor  1608
# transforme a sharpness
# transforme a tensor  1609
# transforme a sharpness
# transforme a tensor  1610
# transforme a sharpness
# transforme a tensor  1611
# transforme a sharpness
# transforme a tensor  1612
# transforme a sharpness
# transforme a tensor  1613
# transforme a sharpness
# transforme a tensor  1614
# transforme a sharpness
# transforme a tensor  1615
# transforme a sharpness
# transforme a tensor  1616
# transforme a sharpness
# transforme a tensor  1617
# transforme a sharpness
# transforme a tensor  1618
# transforme a sharpness
# transforme a tensor  1619
# transforme a sharpness
# transforme a tensor  1620
# transforme a sharpness
# transforme a tensor  1621
# transforme a sharpness
# transforme a tensor  1622
# transforme a sharpness
# transforme a tensor  1623
# transforme a sharpness
# transforme a tensor  1624
# transforme a sharpness
# transforme a tensor  1625
# transforme a sharpness
# transforme a tensor  1626
# transforme a sharpness
# transforme a tensor  1627
# transforme a sharpness
# transforme a tensor  1628
# transforme a sharpness
# transforme a tensor  1629
# transforme a sharpness
# transforme a tensor  1630
# transforme a sharpness
# transforme a tensor  1631
# transforme a sharpness
# transforme a tensor  1632
# transforme a sharpness
# transforme a tensor  1633
# transforme a sharpness
# transforme a tensor  1634
# transforme a sharpness
# transforme a tensor  1635
# transforme a sharpness
# transforme a tensor  1636
# transforme a sharpness
# transforme a tensor  1637
# transforme a sharpness
# transforme a tensor  1638
# transforme a sharpness
# transforme a tensor  1639
# transforme a sharpness
# transforme a tensor  1640
# transforme a sharpness
# transforme a tensor  1641
# transforme a sharpness
# transforme a tensor  1642
# transforme a sharpness
# transforme a tensor  1643
# transforme a sharpness
# transforme a tensor  1644
# transforme a sharpness
# transforme a tensor  1645
# transforme a sharpness
# transforme a tensor  1646
# transforme a sharpness
# transforme a tensor  1647
# transforme a sharpness
# transforme a tensor  1648
# transforme a sharpness
# transforme a tensor  1649
# transforme a sharpness
# transforme a tensor  1650
# transforme a sharpness
# transforme a tensor  1651
# transforme a sharpness
# transforme a tensor  1652
# transforme a sharpness
# transforme a tensor  1653
# transforme a sharpness
# transforme a tensor  1654
# transforme a sharpness
# transforme a tensor  1655
# transforme a sharpness
# transforme a tensor  1656
# transforme a sharpness
# transforme a tensor  1657
# transforme a sharpness
# transforme a tensor  1658
# transforme a sharpness
# transforme a tensor  1659
# transforme a sharpness
# transforme a tensor  1660
# transforme a sharpness
# transforme a tensor  1661
# transforme a sharpness
# transforme a tensor  1662
# transforme a sharpness
# transforme a tensor  1663
# transforme a sharpness
# transforme a tensor  1664
# transforme a sharpness
# transforme a tensor  1665
# transforme a sharpness
# transforme a tensor  1666
# transforme a sharpness
# transforme a tensor  1667
# transforme a sharpness
# transforme a tensor  1668
# transforme a sharpness
# transforme a tensor  1669
# transforme a sharpness
# transforme a tensor  1670
# transforme a sharpness
# transforme a tensor  1671
# transforme a sharpness
# transforme a tensor  1672
# transforme a sharpness
# transforme a tensor  1673
# transforme a sharpness
# transforme a tensor  1674
# transforme a sharpness
# transforme a tensor  1675
# transforme a sharpness
# transforme a tensor  1676
# transforme a sharpness
# transforme a tensor  1677
# transforme a sharpness
# transforme a tensor  1678
# transforme a sharpness
# transforme a tensor  1679
# transforme a sharpness
# transforme a tensor  1680
# transforme a sharpness
# transforme a tensor  1681
# transforme a sharpness
# transforme a tensor  1682
# transforme a sharpness
# transforme a tensor  1683
# transforme a sharpness
# transforme a tensor  1684
# transforme a sharpness
# transforme a tensor  1685
# transforme a sharpness
# transforme a tensor  1686
# transforme a sharpness
# transforme a tensor  1687
# transforme a sharpness
# transforme a tensor  1688
# transforme a sharpness
# transforme a tensor  1689
# transforme a sharpness
# transforme a tensor  1690
# transforme a sharpness
# transforme a tensor  1691
# transforme a sharpness
# transforme a tensor  1692
# transforme a sharpness
# transforme a tensor  1693
# transforme a sharpness
# transforme a tensor  1694
# transforme a sharpness
# transforme a tensor  1695
# transforme a sharpness
# transforme a tensor  1696
# transforme a sharpness
# transforme a tensor  1697
# transforme a sharpness
# transforme a tensor  1698
# transforme a sharpness
# transforme a tensor  1699
# transforme a sharpness
# transforme a tensor  1700
# transforme a sharpness
# transforme a tensor  1701
# transforme a sharpness
# transforme a tensor  1702
# transforme a sharpness
# transforme a tensor  1703
# transforme a sharpness
# transforme a tensor  1704
# transforme a sharpness
# transforme a tensor  1705
# transforme a sharpness
# transforme a tensor  1706
# transforme a sharpness
# transforme a tensor  1707
# transforme a sharpness
# transforme a tensor  1708
# transforme a sharpness
# transforme a tensor  1709
# transforme a sharpness
# transforme a tensor  1710
# transforme a sharpness
# transforme a tensor  1711
# transforme a sharpness
# transforme a tensor  1712
# transforme a sharpness
# transforme a tensor  1713
# transforme a sharpness
# transforme a tensor  1714
# transforme a sharpness
# transforme a tensor  1715
# transforme a sharpness
# transforme a tensor  1716
# transforme a sharpness
# transforme a tensor  1717
# transforme a sharpness
# transforme a tensor  1718
# transforme a sharpness
# transforme a tensor  1719
# transforme a sharpness
# transforme a tensor  1720
# transforme a sharpness
# transforme a tensor  1721
# transforme a sharpness
# transforme a tensor  1722
# transforme a sharpness
# transforme a tensor  1723
# transforme a sharpness
# transforme a tensor  1724
# transforme a sharpness
# transforme a tensor  1725
# transforme a sharpness
# transforme a tensor  1726
# transforme a sharpness
# transforme a tensor  1727
# transforme a sharpness
# transforme a tensor  1728
# transforme a sharpness
# transforme a tensor  1729
# transforme a sharpness
# transforme a tensor  1730
# transforme a sharpness
# transforme a tensor  1731
# transforme a sharpness
# transforme a tensor  1732
# transforme a sharpness
# transforme a tensor  1733
# transforme a sharpness
# transforme a tensor  1734
# transforme a sharpness
# transforme a tensor  1735
# transforme a sharpness
# transforme a tensor  1736
# transforme a sharpness
# transforme a tensor  1737
# transforme a sharpness
# transforme a tensor  1738
# transforme a sharpness
# transforme a tensor  1739
# transforme a sharpness
# transforme a tensor  1740
# transforme a sharpness
# transforme a tensor  1741
# transforme a sharpness
# transforme a tensor  1742
# transforme a sharpness
# transforme a tensor  1743
# transforme a sharpness
# transforme a tensor  1744
# transforme a sharpness
# transforme a tensor  1745
# transforme a sharpness
# transforme a tensor  1746
# transforme a sharpness
# transforme a tensor  1747
# transforme a sharpness
# transforme a tensor  1748
# transforme a sharpness
# transforme a tensor  1749
# transforme a sharpness
# transforme a tensor  1750
# transforme a sharpness
# transforme a tensor  1751
# transforme a sharpness
# transforme a tensor  1752
# transforme a sharpness
# transforme a tensor  1753
# transforme a sharpness
# transforme a tensor  1754
# transforme a sharpness
# transforme a tensor  1755
# transforme a sharpness
# transforme a tensor  1756
# transforme a sharpness
# transforme a tensor  1757
# transforme a sharpness
# transforme a tensor  1758
# transforme a sharpness
# transforme a tensor  1759
# transforme a sharpness
# transforme a tensor  1760
# transforme a sharpness
# transforme a tensor  1761
# transforme a sharpness
# transforme a tensor  1762
# transforme a sharpness
# transforme a tensor  1763
# transforme a sharpness
# transforme a tensor  1764
# transforme a sharpness
# transforme a tensor  1765
# transforme a sharpness
# transforme a tensor  1766
# transforme a sharpness
# transforme a tensor  1767
# transforme a sharpness
# transforme a tensor  1768
# transforme a sharpness
# transforme a tensor  1769
# transforme a sharpness
# transforme a tensor  1770
# transforme a sharpness
# transforme a tensor  1771
# transforme a sharpness
# transforme a tensor  1772
# transforme a sharpness
# transforme a tensor  1773
# transforme a sharpness
# transforme a tensor  1774
# transforme a sharpness
# transforme a tensor  1775
# transforme a sharpness
# transforme a tensor  1776
# transforme a sharpness
# transforme a tensor  1777
# transforme a sharpness
# transforme a tensor  1778
# transforme a sharpness
# transforme a tensor  1779
# transforme a sharpness
# transforme a tensor  1780
# transforme a sharpness
# transforme a tensor  1781
# transforme a sharpness
# transforme a tensor  1782
# transforme a sharpness
# transforme a tensor  1783
# transforme a sharpness
# transforme a tensor  1784
# transforme a sharpness
# transforme a tensor  1785
# transforme a sharpness
# transforme a tensor  1786
# transforme a sharpness
# transforme a tensor  1787
# transforme a sharpness
# transforme a tensor  1788
# transforme a sharpness
# transforme a tensor  1789
# transforme a sharpness
# transforme a tensor  1790
# transforme a sharpness
# transforme a tensor  1791
# transforme a sharpness
# transforme a tensor  1792
# transforme a sharpness
# transforme a tensor  1793
# transforme a sharpness
# transforme a tensor  1794
# transforme a sharpness
# transforme a tensor  1795
# transforme a sharpness
# transforme a tensor  1796
# transforme a sharpness
# transforme a tensor  1797
# transforme a sharpness
# transforme a tensor  1798
# transforme a sharpness
# transforme a tensor  1799
# transforme a sharpness
# transforme a tensor  1800
# transforme a sharpness
# transforme a tensor  1801
# transforme a sharpness
# transforme a tensor  1802
# transforme a sharpness
# transforme a tensor  1803
# transforme a sharpness
# transforme a tensor  1804
# transforme a sharpness
# transforme a tensor  1805
# transforme a sharpness
# transforme a tensor  1806
# transforme a sharpness
# transforme a tensor  1807
# transforme a sharpness
# transforme a tensor  1808
# transforme a sharpness
# transforme a tensor  1809
# transforme a sharpness
# transforme a tensor  1810
# transforme a sharpness
# transforme a tensor  1811
# transforme a sharpness
# transforme a tensor  1812
# transforme a sharpness
# transforme a tensor  1813
# transforme a sharpness
# transforme a tensor  1814
# transforme a sharpness
# transforme a tensor  1815
# transforme a sharpness
# transforme a tensor  1816
# transforme a sharpness
# transforme a tensor  1817
# transforme a sharpness
# transforme a tensor  1818
# transforme a sharpness
# transforme a tensor  1819
# transforme a sharpness
# transforme a tensor  1820
# transforme a sharpness
# transforme a tensor  1821
# transforme a sharpness
# transforme a tensor  1822
# transforme a sharpness
# transforme a tensor  1823
# transforme a sharpness
# transforme a tensor  1824
# transforme a sharpness
# transforme a tensor  1825
# transforme a sharpness
# transforme a tensor  1826
# transforme a sharpness
# transforme a tensor  1827
# transforme a sharpness
# transforme a tensor  1828
# transforme a sharpness
# transforme a tensor  1829
# transforme a sharpness
# transforme a tensor  1830
# transforme a sharpness
# transforme a tensor  1831
# transforme a sharpness
# transforme a tensor  1832
# transforme a sharpness
# transforme a tensor  1833
# transforme a sharpness
# transforme a tensor  1834
# transforme a sharpness
# transforme a tensor  1835
# transforme a sharpness
# transforme a tensor  1836
# transforme a sharpness
# transforme a tensor  1837
# transforme a sharpness
# transforme a tensor  1838
# transforme a sharpness
# transforme a tensor  1839
# transforme a sharpness
# transforme a tensor  1840
# transforme a sharpness
# transforme a tensor  1841
# transforme a sharpness
# transforme a tensor  1842
# transforme a sharpness
# transforme a tensor  1843
# transforme a sharpness
# transforme a tensor  1844
# transforme a sharpness
# transforme a tensor  1845
# transforme a sharpness
# transforme a tensor  1846
# transforme a sharpness
# transforme a tensor  1847
# transforme a sharpness
# transforme a tensor  1848
# transforme a sharpness
# transforme a tensor  1849
# transforme a sharpness
# transforme a tensor  1850
# transforme a sharpness
# transforme a tensor  1851
# transforme a sharpness
# transforme a tensor  1852
# transforme a sharpness
# transforme a tensor  1853
# transforme a sharpness
# transforme a tensor  1854
# transforme a sharpness
# transforme a tensor  1855
# transforme a sharpness
# transforme a tensor  1856
# transforme a sharpness
# transforme a tensor  1857
# transforme a sharpness
# transforme a tensor  1858
# transforme a sharpness
# transforme a tensor  1859
# transforme a sharpness
# transforme a tensor  1860
# transforme a sharpness
# transforme a tensor  1861
# transforme a sharpness
# transforme a tensor  1862
# transforme a sharpness
# transforme a tensor  1863
# transforme a sharpness
# transforme a tensor  1864
# transforme a sharpness
# transforme a tensor  1865
# transforme a sharpness
# transforme a tensor  1866
# transforme a sharpness
# transforme a tensor  1867
# transforme a sharpness
# transforme a tensor  1868
# transforme a sharpness
# transforme a tensor  1869
# transforme a sharpness
# transforme a tensor  1870
# transforme a sharpness
# transforme a tensor  1871
# transforme a sharpness
# transforme a tensor  1872
# transforme a sharpness
# transforme a tensor  1873
# transforme a sharpness
# transforme a tensor  1874
# transforme a sharpness
# transforme a tensor  1875
# transforme a sharpness
# transforme a tensor  1876
# transforme a sharpness
# transforme a tensor  1877
# transforme a sharpness
# transforme a tensor  1878
# transforme a sharpness
# transforme a tensor  1879
# transforme a sharpness
# transforme a tensor  1880
# transforme a sharpness
# transforme a tensor  1881
# transforme a sharpness
# transforme a tensor  1882
# transforme a sharpness
# transforme a tensor  1883
# transforme a sharpness
# transforme a tensor  1884
# transforme a sharpness
# transforme a tensor  1885
# transforme a sharpness
# transforme a tensor  1886
# transforme a sharpness
# transforme a tensor  1887
# transforme a sharpness
# transforme a tensor  1888
# transforme a sharpness
# transforme a tensor  1889
# transforme a sharpness
# transforme a tensor  1890
# transforme a sharpness
# transforme a tensor  1891
# transforme a sharpness
# transforme a tensor  1892
# transforme a sharpness
# transforme a tensor  1893
# transforme a sharpness
# transforme a tensor  1894
# transforme a sharpness
# transforme a tensor  1895
# transforme a sharpness
# transforme a tensor  1896
# transforme a sharpness
# transforme a tensor  1897
# transforme a sharpness
# transforme a tensor  1898
# transforme a sharpness
# transforme a tensor  1899
# transforme a sharpness
# transforme a tensor  1900
# transforme a sharpness
# transforme a tensor  1901
# transforme a sharpness
# transforme a tensor  1902
# transforme a sharpness
# transforme a tensor  1903
# transforme a sharpness
# transforme a tensor  1904
# transforme a sharpness
# transforme a tensor  1905
# transforme a sharpness
# transforme a tensor  1906
# transforme a sharpness
# transforme a tensor  1907
# transforme a sharpness
# transforme a tensor  1908
# transforme a sharpness
# transforme a tensor  1909
# transforme a sharpness
# transforme a tensor  1910
# transforme a sharpness
# transforme a tensor  1911
# transforme a sharpness
# transforme a tensor  1912
# transforme a sharpness
# transforme a tensor  1913
# transforme a sharpness
# transforme a tensor  1914
# transforme a sharpness
# transforme a tensor  1915
# transforme a sharpness
# transforme a tensor  1916
# transforme a sharpness
# transforme a tensor  1917
# transforme a sharpness
# transforme a tensor  1918
# transforme a sharpness
# transforme a tensor  1919
# transforme a sharpness
# transforme a tensor  1920
# transforme a sharpness
# transforme a tensor  1921
# transforme a sharpness
# transforme a tensor  1922
# transforme a sharpness
# transforme a tensor  1923
# transforme a sharpness
# transforme a tensor  1924
# transforme a sharpness
# transforme a tensor  1925
# transforme a sharpness
# transforme a tensor  1926
# transforme a sharpness
# transforme a tensor  1927
# transforme a sharpness
# transforme a tensor  1928
# transforme a sharpness
# transforme a tensor  1929
# transforme a sharpness
# transforme a tensor  1930
# transforme a sharpness
# transforme a tensor  1931
# transforme a sharpness
# transforme a tensor  1932
# transforme a sharpness
# transforme a tensor  1933
# transforme a sharpness
# transforme a tensor  1934
# transforme a sharpness
# transforme a tensor  1935
# transforme a sharpness
# transforme a tensor  1936
# transforme a sharpness
# transforme a tensor  1937
# transforme a sharpness
# transforme a tensor  1938
# transforme a sharpness
# transforme a tensor  1939
# transforme a sharpness
# transforme a tensor  1940
# transforme a sharpness
# transforme a tensor  1941
# transforme a sharpness
# transforme a tensor  1942
# transforme a sharpness
# transforme a tensor  1943
# transforme a sharpness
# transforme a tensor  1944
# transforme a sharpness
# transforme a tensor  1945
# transforme a sharpness
# transforme a tensor  1946
# transforme a sharpness
# transforme a tensor  1947
# transforme a sharpness
# transforme a tensor  1948
# transforme a sharpness
# transforme a tensor  1949
# transforme a sharpness
# transforme a tensor  1950
# transforme a sharpness
# transforme a tensor  1951
# transforme a sharpness
# transforme a tensor  1952
# transforme a sharpness
# transforme a tensor  1953
# transforme a sharpness
# transforme a tensor  1954
# transforme a sharpness
# transforme a tensor  1955
# transforme a sharpness
# transforme a tensor  1956
# transforme a sharpness
# transforme a tensor  1957
# transforme a sharpness
# transforme a tensor  1958
# transforme a sharpness
# transforme a tensor  1959
# transforme a sharpness
# transforme a tensor  1960
# transforme a sharpness
# transforme a tensor  1961
# transforme a sharpness
# transforme a tensor  1962
# transforme a sharpness
# transforme a tensor  1963
# transforme a sharpness
# transforme a tensor  1964
# transforme a sharpness
# transforme a tensor  1965
# transforme a sharpness
# transforme a tensor  1966
# transforme a sharpness
# transforme a tensor  1967
# transforme a sharpness
# transforme a tensor  1968
# transforme a sharpness
# transforme a tensor  1969
# transforme a sharpness
# transforme a tensor  1970
# transforme a sharpness
# transforme a tensor  1971
# transforme a sharpness
# transforme a tensor  1972
# transforme a sharpness
# transforme a tensor  1973
# transforme a sharpness
# transforme a tensor  1974
# transforme a sharpness
# transforme a tensor  1975
# transforme a sharpness
# transforme a tensor  1976
# transforme a sharpness
# transforme a tensor  1977
# transforme a sharpness
# transforme a tensor  1978
# transforme a sharpness
# transforme a tensor  1979
# transforme a sharpness
# transforme a tensor  1980
# transforme a sharpness
# transforme a tensor  1981
# transforme a sharpness
# transforme a tensor  1982
# transforme a sharpness
# transforme a tensor  1983
# transforme a sharpness
# transforme a tensor  1984
# transforme a sharpness
# transforme a tensor  1985
# transforme a sharpness
# transforme a tensor  1986
# transforme a sharpness
# transforme a tensor  1987
# transforme a sharpness
# transforme a tensor  1988
# transforme a sharpness
# transforme a tensor  1989
# transforme a sharpness
# transforme a tensor  1990
# transforme a sharpness
# transforme a tensor  1991
# transforme a sharpness
# transforme a tensor  1992
# transforme a sharpness
# transforme a tensor  1993
# transforme a sharpness
# transforme a tensor  1994
# transforme a sharpness
# transforme a tensor  1995
# transforme a sharpness
# transforme a tensor  1996
# transforme a sharpness
# transforme a tensor  1997
# transforme a sharpness
# transforme a tensor  1998
# transforme a sharpness
# transforme a tensor  1999
# transforme a sharpness
# transforme a tensor  2000
# transforme a sharpness
# transforme a tensor  2001
# transforme a sharpness
# transforme a tensor  2002
# transforme a sharpness
# transforme a tensor  2003
# transforme a sharpness
# transforme a tensor  2004
# transforme a sharpness
# transforme a tensor  2005
# transforme a sharpness
# transforme a tensor  2006
# transforme a sharpness
# transforme a tensor  2007
# transforme a sharpness
# transforme a tensor  2008
# transforme a sharpness
# transforme a tensor  2009
# transforme a sharpness
# transforme a tensor  2010
# transforme a sharpness
# transforme a tensor  2011
# transforme a sharpness
# transforme a tensor  2012
# transforme a sharpness
# transforme a tensor  2013
# transforme a sharpness
# transforme a tensor  2014
# transforme a sharpness
# transforme a tensor  2015
# transforme a sharpness
# transforme a tensor  2016
# transforme a sharpness
# transforme a tensor  2017
# transforme a sharpness
# transforme a tensor  2018
# transforme a sharpness
# transforme a tensor  2019
# transforme a sharpness
# transforme a tensor  2020
# transforme a sharpness
# transforme a tensor  2021
# transforme a sharpness
# transforme a tensor  2022
# transforme a sharpness
# transforme a tensor  2023
# transforme a sharpness
# transforme a tensor  2024
# transforme a sharpness
# transforme a tensor  2025
# transforme a sharpness
# transforme a tensor  2026
# transforme a sharpness
# transforme a tensor  2027
# transforme a sharpness
# transforme a tensor  2028
# transforme a sharpness
# transforme a tensor  2029
# transforme a sharpness
# transforme a tensor  2030
# transforme a sharpness
# transforme a tensor  2031
# transforme a sharpness
# transforme a tensor  2032
# transforme a sharpness
# transforme a tensor  2033
# transforme a sharpness
# transforme a tensor  2034
# transforme a sharpness
# transforme a tensor  2035
# transforme a sharpness
# transforme a tensor  2036
# transforme a sharpness
# transforme a tensor  2037
# transforme a sharpness
# transforme a tensor  2038
# transforme a sharpness
# transforme a tensor  2039
# transforme a sharpness
# transforme a tensor  2040
# transforme a sharpness
# transforme a tensor  2041
# transforme a sharpness
# transforme a tensor  2042
# transforme a sharpness
# transforme a tensor  2043
# transforme a sharpness
# transforme a tensor  2044
# transforme a sharpness
# transforme a tensor  2045
# transforme a sharpness
# transforme a tensor  2046
# transforme a sharpness
# transforme a tensor  2047
# transforme a sharpness
# transforme a tensor  2048
# transforme a sharpness
# transforme a tensor  2049
# transforme a sharpness
# transforme a tensor  2050
# transforme a sharpness
# transforme a tensor  2051
# transforme a sharpness
# transforme a tensor  2052
# transforme a sharpness
# transforme a tensor  2053
# transforme a sharpness
# transforme a tensor  2054
# transforme a sharpness
# transforme a tensor  2055
# transforme a sharpness
# transforme a tensor  2056
# transforme a sharpness
# transforme a tensor  2057
# transforme a sharpness
# transforme a tensor  2058
# transforme a sharpness
# transforme a tensor  2059
# transforme a sharpness
# transforme a tensor  2060
# transforme a sharpness
# transforme a tensor  2061
# transforme a sharpness
# transforme a tensor  2062
# transforme a sharpness
# transforme a tensor  2063
# transforme a sharpness
# transforme a tensor  2064
# transforme a sharpness
# transforme a tensor  2065
# transforme a sharpness
# transforme a tensor  2066
# transforme a sharpness
# transforme a tensor  2067
# transforme a sharpness
# transforme a tensor  2068
# transforme a sharpness
# transforme a tensor  2069
# transforme a sharpness
# transforme a tensor  2070
# transforme a sharpness
# transforme a tensor  2071
# transforme a sharpness
# transforme a tensor  2072
# transforme a sharpness
# transforme a tensor  2073
# transforme a sharpness
# transforme a tensor  2074
# transforme a sharpness
# transforme a tensor  2075
# transforme a sharpness
# transforme a tensor  2076
# transforme a sharpness
# transforme a tensor  2077
# transforme a sharpness
# transforme a tensor  2078
# transforme a sharpness
# transforme a tensor  2079
# transforme a sharpness
# transforme a tensor  2080
# transforme a sharpness
# transforme a tensor  2081
# transforme a sharpness
# transforme a tensor  2082
# transforme a sharpness
# transforme a tensor  2083
# transforme a sharpness
# transforme a tensor  2084
# transforme a sharpness
# transforme a tensor  2085
# transforme a sharpness
# transforme a tensor  2086
# transforme a sharpness
# transforme a tensor  2087
# transforme a sharpness
# transforme a tensor  2088
# transforme a sharpness
# transforme a tensor  2089
# transforme a sharpness
# transforme a tensor  2090
# transforme a sharpness
# transforme a tensor  2091
# transforme a sharpness
# transforme a tensor  2092
# transforme a sharpness
# transforme a tensor  2093
# transforme a sharpness
# transforme a tensor  2094
# transforme a sharpness
# transforme a tensor  2095
# transforme a sharpness
# transforme a tensor  2096
# transforme a sharpness
# transforme a tensor  2097
# transforme a sharpness
# transforme a tensor  2098
# transforme a sharpness
# transforme a tensor  2099
# transforme a sharpness
# transforme a tensor  2100
# transforme a sharpness
# transforme a tensor  2101
# transforme a sharpness
# transforme a tensor  2102
# transforme a sharpness
# transforme a tensor  2103
# transforme a sharpness
# transforme a tensor  2104
# transforme a sharpness
# transforme a tensor  2105
# transforme a sharpness
# transforme a tensor  2106
# transforme a sharpness
# transforme a tensor  2107
# transforme a sharpness
# transforme a tensor  2108
# transforme a sharpness
# transforme a tensor  2109
# transforme a sharpness
# transforme a tensor  2110
# transforme a sharpness
# transforme a tensor  2111
# transforme a sharpness
# transforme a tensor  2112
# transforme a sharpness
# transforme a tensor  2113
# transforme a sharpness
# transforme a tensor  2114
# transforme a sharpness
# transforme a tensor  2115
# transforme a sharpness
# transforme a tensor  2116
# transforme a sharpness
# transforme a tensor  2117
# transforme a sharpness
# transforme a tensor  2118
# transforme a sharpness
# transforme a tensor  2119
# transforme a sharpness
# transforme a tensor  2120
# transforme a sharpness
# transforme a tensor  2121
# transforme a sharpness
# transforme a tensor  2122
# transforme a sharpness
# transforme a tensor  2123
# transforme a sharpness
# transforme a tensor  2124
# transforme a sharpness
# transforme a tensor  2125
# transforme a sharpness
# transforme a tensor  2126
# transforme a sharpness
# transforme a tensor  2127
# transforme a sharpness
# transforme a tensor  2128
# transforme a sharpness
# transforme a tensor  2129
# transforme a sharpness
# transforme a tensor  2130
# transforme a sharpness
# transforme a tensor  2131
# transforme a sharpness
# transforme a tensor  2132
# transforme a sharpness
# transforme a tensor  2133
# transforme a sharpness
# transforme a tensor  2134
# transforme a sharpness
# transforme a tensor  2135
# transforme a sharpness
# transforme a tensor  2136
# transforme a sharpness
# transforme a tensor  2137
# transforme a sharpness
# transforme a tensor  2138
# transforme a sharpness
# transforme a tensor  2139
# transforme a sharpness
# transforme a tensor  2140
# transforme a sharpness
# transforme a tensor  2141
# transforme a sharpness
# transforme a tensor  2142
# transforme a sharpness
# transforme a tensor  2143
# transforme a sharpness
# transforme a tensor  2144
# transforme a sharpness
# transforme a tensor  2145
# transforme a sharpness
# transforme a tensor  2146
# transforme a sharpness
# transforme a tensor  2147
# transforme a sharpness
# transforme a tensor  2148
# transforme a sharpness
# transforme a tensor  2149
# transforme a sharpness
# transforme a tensor  2150
# transforme a sharpness
# transforme a tensor  2151
# transforme a sharpness
# transforme a tensor  2152
# transforme a sharpness
# transforme a tensor  2153
# transforme a sharpness
# transforme a tensor  2154
# transforme a sharpness
# transforme a tensor  2155
# transforme a sharpness
# transforme a tensor  2156
# transforme a sharpness
# transforme a tensor  2157
# transforme a sharpness
# transforme a tensor  2158
# transforme a sharpness
# transforme a tensor  2159
# transforme a sharpness
# transforme a tensor  2160
# transforme a sharpness
# transforme a tensor  2161
# transforme a sharpness
# transforme a tensor  2162
# transforme a sharpness
# transforme a tensor  2163
# transforme a sharpness
# transforme a tensor  2164
# transforme a sharpness
# transforme a tensor  2165
# transforme a sharpness
# transforme a tensor  2166
# transforme a sharpness
# transforme a tensor  2167
# transforme a sharpness
# transforme a tensor  2168
# transforme a sharpness
# transforme a tensor  2169
# transforme a sharpness
# transforme a tensor  2170
# transforme a sharpness
# transforme a tensor  2171
# transforme a sharpness
# transforme a tensor  2172
# transforme a sharpness
# transforme a tensor  2173
# transforme a sharpness
# transforme a tensor  2174
# transforme a sharpness
# transforme a tensor  2175
# transforme a sharpness
# transforme a tensor  2176
# transforme a sharpness
# transforme a tensor  2177
# transforme a sharpness
# transforme a tensor  2178
# transforme a sharpness
# transforme a tensor  2179
# transforme a sharpness
# transforme a tensor  2180
# transforme a sharpness
# transforme a tensor  2181
# transforme a sharpness
# transforme a tensor  2182
# transforme a sharpness
# transforme a tensor  2183
# transforme a sharpness
# transforme a tensor  2184
# transforme a sharpness
# transforme a tensor  2185
# transforme a sharpness
# transforme a tensor  2186
# transforme a sharpness
# transforme a tensor  2187
# transforme a sharpness
# transforme a tensor  2188
# transforme a sharpness
# transforme a tensor  2189
# transforme a sharpness
# transforme a tensor  2190
# transforme a sharpness
# transforme a tensor  2191
# transforme a sharpness
# transforme a tensor  2192
# transforme a sharpness
# transforme a tensor  2193
# transforme a sharpness
# transforme a tensor  2194
# transforme a sharpness
# transforme a tensor  2195
# transforme a sharpness
# transforme a tensor  2196
# transforme a sharpness
# transforme a tensor  2197
# transforme a sharpness
# transforme a tensor  2198
# transforme a sharpness
# transforme a tensor  2199
# transforme a sharpness
# transforme a tensor  2200
# transforme a sharpness
# transforme a tensor  2201
# transforme a sharpness
# transforme a tensor  2202
# transforme a sharpness
# transforme a tensor  2203
# transforme a sharpness
# transforme a tensor  2204
# transforme a sharpness
# transforme a tensor  2205
# transforme a sharpness
# transforme a tensor  2206
# transforme a sharpness
# transforme a tensor  2207
# transforme a sharpness
# transforme a tensor  2208
# transforme a sharpness
# transforme a tensor  2209
# transforme a sharpness
# transforme a tensor  2210
# transforme a sharpness
# transforme a tensor  2211
# transforme a sharpness
# transforme a tensor  2212
# transforme a sharpness
# transforme a tensor  2213
# transforme a sharpness
# transforme a tensor  2214
# transforme a sharpness
# transforme a tensor  2215
# transforme a sharpness
# transforme a tensor  2216
# transforme a sharpness
# transforme a tensor  2217
# transforme a sharpness
# transforme a tensor  2218
# transforme a sharpness
# transforme a tensor  2219
# transforme a sharpness
# transforme a tensor  2220
# transforme a sharpness
# transforme a tensor  2221
# transforme a sharpness
# transforme a tensor  2222
# transforme a sharpness
# transforme a tensor  2223
# transforme a sharpness
# transforme a tensor  2224
# transforme a sharpness
# transforme a tensor  2225
# transforme a sharpness
# transforme a tensor  2226
# transforme a sharpness
# transforme a tensor  2227
# transforme a sharpness
# transforme a tensor  2228
# transforme a sharpness
# transforme a tensor  2229
# transforme a sharpness
# transforme a tensor  2230
# transforme a sharpness
# transforme a tensor  2231
# transforme a sharpness
# transforme a tensor  2232
# transforme a sharpness
# transforme a tensor  2233
# transforme a sharpness
# transforme a tensor  2234
# transforme a sharpness
# transforme a tensor  2235
# transforme a sharpness
# transforme a tensor  2236
# transforme a sharpness
# transforme a tensor  2237
# transforme a sharpness
# transforme a tensor  2238
# transforme a sharpness
# transforme a tensor  2239
# transforme a sharpness
# transforme a tensor  2240
# transforme a sharpness
# transforme a tensor  2241
# transforme a sharpness
# transforme a tensor  2242
# transforme a sharpness
# transforme a tensor  2243
# transforme a sharpness
# transforme a tensor  2244
# transforme a sharpness
# transforme a tensor  2245
# transforme a sharpness
# transforme a tensor  2246
# transforme a sharpness
# transforme a tensor  2247
# transforme a sharpness
# transforme a tensor  2248
# transforme a sharpness
# transforme a tensor  2249
# transforme a sharpness
# transforme a tensor  2250
# transforme a sharpness
# transforme a tensor  2251
# transforme a sharpness
# transforme a tensor  2252
# transforme a sharpness
# transforme a tensor  2253
# transforme a sharpness
# transforme a tensor  2254
# transforme a sharpness
# transforme a tensor  2255
# transforme a sharpness
# transforme a tensor  2256
# transforme a sharpness
# transforme a tensor  2257
# transforme a sharpness
# transforme a tensor  2258
# transforme a sharpness
# transforme a tensor  2259
# transforme a sharpness
# transforme a tensor  2260
# transforme a sharpness
# transforme a tensor  2261
# transforme a sharpness
# transforme a tensor  2262
# transforme a sharpness
# transforme a tensor  2263
# transforme a sharpness
# transforme a tensor  2264
# transforme a sharpness
# transforme a tensor  2265
# transforme a sharpness
# transforme a tensor  2266
# transforme a sharpness
# transforme a tensor  2267
# transforme a sharpness
# transforme a tensor  2268
# transforme a sharpness
# transforme a tensor  2269
# transforme a sharpness
# transforme a tensor  2270
# transforme a sharpness
# transforme a tensor  2271
# transforme a sharpness
# transforme a tensor  2272
# transforme a sharpness
# transforme a tensor  2273
# transforme a sharpness
# transforme a tensor  2274
# transforme a sharpness
# transforme a tensor  2275
# transforme a sharpness
# transforme a tensor  2276
# transforme a sharpness
# transforme a tensor  2277
# transforme a sharpness
# transforme a tensor  2278
# transforme a sharpness
# transforme a tensor  2279
# transforme a sharpness
# transforme a tensor  2280
# transforme a sharpness
# transforme a tensor  2281
# transforme a sharpness
# transforme a tensor  2282
# transforme a sharpness
# transforme a tensor  2283
# transforme a sharpness
# transforme a tensor  2284
# transforme a sharpness
# transforme a tensor  2285
# transforme a sharpness
# transforme a tensor  2286
# transforme a sharpness
# transforme a tensor  2287
# transforme a sharpness
# transforme a tensor  2288
# transforme a sharpness
# transforme a tensor  2289
# transforme a sharpness
# transforme a tensor  2290
# transforme a sharpness
# transforme a tensor  2291
# transforme a sharpness
# transforme a tensor  2292
# transforme a sharpness
# transforme a tensor  2293
# transforme a sharpness
# transforme a tensor  2294
# transforme a sharpness
# transforme a tensor  2295
# transforme a sharpness
# transforme a tensor  2296
# transforme a sharpness
# transforme a tensor  2297
# transforme a sharpness
# transforme a tensor  2298
# transforme a sharpness
# transforme a tensor  2299
# transforme a sharpness
# transforme a tensor  2300
# transforme a sharpness
# transforme a tensor  2301
# transforme a sharpness
# transforme a tensor  2302
# transforme a sharpness
# transforme a tensor  2303
# transforme a sharpness
# transforme a tensor  2304
# transforme a sharpness
# transforme a tensor  2305
# transforme a sharpness
# transforme a tensor  2306
# transforme a sharpness
# transforme a tensor  2307
# transforme a sharpness
# transforme a tensor  2308
# transforme a sharpness
# transforme a tensor  2309
# transforme a sharpness
# transforme a tensor  2310
# transforme a sharpness
# transforme a tensor  2311
# transforme a sharpness
# transforme a tensor  2312
# transforme a sharpness
# transforme a tensor  2313
# transforme a sharpness
# transforme a tensor  2314
# transforme a sharpness
# transforme a tensor  2315
# transforme a sharpness
# transforme a tensor  2316
# transforme a sharpness
# transforme a tensor  2317
# transforme a sharpness
# transforme a tensor  2318
# transforme a sharpness
# transforme a tensor  2319
# transforme a sharpness
# transforme a tensor  2320
# transforme a sharpness
# transforme a tensor  2321
# transforme a sharpness
# transforme a tensor  2322
# transforme a sharpness
# transforme a tensor  2323
# transforme a sharpness
# transforme a tensor  2324
# transforme a sharpness
# transforme a tensor  2325
# transforme a sharpness
# transforme a tensor  2326
# transforme a sharpness
# transforme a tensor  2327
# transforme a sharpness
# transforme a tensor  2328
# transforme a sharpness
# transforme a tensor  2329
# transforme a sharpness
# transforme a tensor  2330
# transforme a sharpness
# transforme a tensor  2331
# transforme a sharpness
# transforme a tensor  2332
# transforme a sharpness
# transforme a tensor  2333
# transforme a sharpness
# transforme a tensor  2334
# transforme a sharpness
# transforme a tensor  2335
# transforme a sharpness
# transforme a tensor  2336
# transforme a sharpness
# transforme a tensor  2337
# transforme a sharpness
# transforme a tensor  2338
# transforme a sharpness
# transforme a tensor  2339
# transforme a sharpness
# transforme a tensor  2340
# transforme a sharpness
# transforme a tensor  2341
# transforme a sharpness
# transforme a tensor  2342
# transforme a sharpness
# transforme a tensor  2343
# transforme a sharpness
# transforme a tensor  2344
# transforme a sharpness
# transforme a tensor  2345
# transforme a sharpness
# transforme a tensor  2346
# transforme a sharpness
# transforme a tensor  2347
# transforme a sharpness
# transforme a tensor  2348
# transforme a sharpness
# transforme a tensor  2349
# transforme a sharpness
# transforme a tensor  2350
# transforme a sharpness
# transforme a tensor  2351
# transforme a sharpness
# transforme a tensor  2352
# transforme a sharpness
# transforme a tensor  2353
# transforme a sharpness
# transforme a tensor  2354
# transforme a sharpness
# transforme a tensor  2355
# transforme a sharpness
# transforme a tensor  2356
# transforme a sharpness
# transforme a tensor  2357
# transforme a sharpness
# transforme a tensor  2358
# transforme a sharpness
# transforme a tensor  2359
# transforme a sharpness
# transforme a tensor  2360
# transforme a sharpness
# transforme a tensor  2361
# transforme a sharpness
# transforme a tensor  2362
# transforme a sharpness
# transforme a tensor  2363
# transforme a sharpness
# transforme a tensor  2364
# transforme a sharpness
# transforme a tensor  2365
# transforme a sharpness
# transforme a tensor  2366
# transforme a sharpness
# transforme a tensor  2367
# transforme a sharpness
# transforme a tensor  2368
# transforme a sharpness
# transforme a tensor  2369
# transforme a sharpness
# transforme a tensor  2370
# transforme a sharpness
# transforme a tensor  2371
# transforme a sharpness
# transforme a tensor  2372
# transforme a sharpness
# transforme a tensor  2373
# transforme a sharpness
# transforme a tensor  2374
# transforme a sharpness
# transforme a tensor  2375
# transforme a sharpness
# transforme a tensor  2376
# transforme a sharpness
# transforme a tensor  2377
# transforme a sharpness
# transforme a tensor  2378
# transforme a sharpness
# transforme a tensor  2379
# transforme a sharpness
# transforme a tensor  2380
# transforme a sharpness
# transforme a tensor  2381
# transforme a sharpness
# transforme a tensor  2382
# transforme a sharpness
# transforme a tensor  2383
# transforme a sharpness
# transforme a tensor  2384
# transforme a sharpness
# transforme a tensor  2385
# transforme a sharpness
# transforme a tensor  2386
# transforme a sharpness
# transforme a tensor  2387
# transforme a sharpness
# transforme a tensor  2388
# transforme a sharpness
# transforme a tensor  2389
# transforme a sharpness
# transforme a tensor  2390
# transforme a sharpness
# transforme a tensor  2391
# transforme a sharpness
# transforme a tensor  2392
# transforme a sharpness
# transforme a tensor  2393
# transforme a sharpness
# transforme a tensor  2394
# transforme a sharpness
# transforme a tensor  2395
# transforme a sharpness
# transforme a tensor  2396
# transforme a sharpness
# transforme a tensor  2397
# transforme a sharpness
# transforme a tensor  2398
# transforme a sharpness
# transforme a tensor  2399
# transforme a sharpness
# transforme a tensor  2400
# transforme a sharpness
# transforme a tensor  2401
# transforme a sharpness
# transforme a tensor  2402
# transforme a sharpness
# transforme a tensor  2403
# transforme a sharpness
# transforme a tensor  2404
# transforme a sharpness
# transforme a tensor  2405
# transforme a sharpness
# transforme a tensor  2406
# transforme a sharpness
# transforme a tensor  2407
# transforme a sharpness
# transforme a tensor  2408
# transforme a sharpness
# transforme a tensor  2409
# transforme a sharpness
# transforme a tensor  2410
# transforme a sharpness
# transforme a tensor  2411
# transforme a sharpness
# transforme a tensor  2412
# transforme a sharpness
# transforme a tensor  2413
# transforme a sharpness
# transforme a tensor  2414
# transforme a sharpness
# transforme a tensor  2415
# transforme a sharpness
# transforme a tensor  2416
# transforme a sharpness
# transforme a tensor  2417
# transforme a sharpness
# transforme a tensor  2418
# transforme a sharpness
# transforme a tensor  2419
# transforme a sharpness
# transforme a tensor  2420
# transforme a sharpness
# transforme a tensor  2421
# transforme a sharpness
# transforme a tensor  2422
# transforme a sharpness
# transforme a tensor  2423
# transforme a sharpness
# transforme a tensor  2424
# transforme a sharpness
# transforme a tensor  2425
# transforme a sharpness
# transforme a tensor  2426
# transforme a sharpness
# transforme a tensor  2427
# transforme a sharpness
# transforme a tensor  2428
# transforme a sharpness
# transforme a tensor  2429
# transforme a sharpness
# transforme a tensor  2430
# transforme a sharpness
# transforme a tensor  2431
# transforme a sharpness
# transforme a tensor  2432
# transforme a sharpness
# transforme a tensor  2433
# transforme a sharpness
# transforme a tensor  2434
# transforme a sharpness
# transforme a tensor  2435
# transforme a sharpness
# transforme a tensor  2436
# transforme a sharpness
# transforme a tensor  2437
# transforme a sharpness
# transforme a tensor  2438
# transforme a sharpness
# transforme a tensor  2439
# transforme a sharpness
# transforme a tensor  2440
# transforme a sharpness
# transforme a tensor  2441
# transforme a sharpness
# transforme a tensor  2442
# transforme a sharpness
# transforme a tensor  2443
# transforme a sharpness
# transforme a tensor  2444
# transforme a sharpness
# transforme a tensor  2445
# transforme a sharpness
# transforme a tensor  2446
# transforme a sharpness
# transforme a tensor  2447
# transforme a sharpness
# transforme a tensor  2448
# transforme a sharpness
# transforme a tensor  2449
# transforme a sharpness
# transforme a tensor  2450
# transforme a sharpness
# transforme a tensor  2451
# transforme a sharpness
# transforme a tensor  2452
# transforme a sharpness
# transforme a tensor  2453
# transforme a sharpness
# transforme a tensor  2454
# transforme a sharpness
# transforme a tensor  2455
# transforme a sharpness
# transforme a tensor  2456
# transforme a sharpness
# transforme a tensor  2457
# transforme a sharpness
# transforme a tensor  2458
# transforme a sharpness
# transforme a tensor  2459
# transforme a sharpness
# transforme a tensor  2460
# transforme a sharpness
# transforme a tensor  2461
# transforme a sharpness
# transforme a tensor  2462
# transforme a sharpness
# transforme a tensor  2463
# transforme a sharpness
# transforme a tensor  2464
# transforme a sharpness
# transforme a tensor  2465
# transforme a sharpness
# transforme a tensor  2466
# transforme a sharpness
# transforme a tensor  2467
# transforme a sharpness
# transforme a tensor  2468
# transforme a sharpness
# transforme a tensor  2469
# transforme a sharpness
# transforme a tensor  2470
# transforme a sharpness
# transforme a tensor  2471
# transforme a sharpness
# transforme a tensor  2472
# transforme a sharpness
# transforme a tensor  2473
# transforme a sharpness
# transforme a tensor  2474
# transforme a sharpness
# transforme a tensor  2475
# transforme a sharpness
# transforme a tensor  2476
# transforme a sharpness
# transforme a tensor  2477
# transforme a sharpness
# transforme a tensor  2478
# transforme a sharpness
# transforme a tensor  2479
# transforme a sharpness
# transforme a tensor  2480
# transforme a sharpness
# transforme a tensor  2481
# transforme a sharpness
# transforme a tensor  2482
# transforme a sharpness
# transforme a tensor  2483
# transforme a sharpness
# transforme a tensor  2484
# transforme a sharpness
# transforme a tensor  2485
# transforme a sharpness
# transforme a tensor  2486
# transforme a sharpness
# transforme a tensor  2487
# transforme a sharpness
# transforme a tensor  2488
# transforme a sharpness
# transforme a tensor  2489
# transforme a sharpness
# transforme a tensor  2490
# transforme a sharpness
# transforme a tensor  2491
# transforme a sharpness
# transforme a tensor  2492
# transforme a sharpness
# transforme a tensor  2493
# transforme a sharpness
# transforme a tensor  2494
# transforme a sharpness
# transforme a tensor  2495
# transforme a sharpness
# transforme a tensor  2496
# transforme a sharpness
# transforme a tensor  2497
# transforme a sharpness
# transforme a tensor  2498
# transforme a sharpness
# transforme a tensor  2499
# transforme a sharpness
# transforme a tensor  2500
# transforme a sharpness
# transforme a tensor  2501
# transforme a sharpness
# transforme a tensor  2502
# transforme a sharpness
# transforme a tensor  2503
# transforme a sharpness
# transforme a tensor  2504
# transforme a sharpness
# transforme a tensor  2505
# transforme a sharpness
# transforme a tensor  2506
# transforme a sharpness
# transforme a tensor  2507
# transforme a sharpness
# transforme a tensor  2508
# transforme a sharpness
# transforme a tensor  2509
# transforme a sharpness
# transforme a tensor  2510
# transforme a sharpness
# transforme a tensor  2511
# transforme a sharpness
# transforme a tensor  2512
# transforme a sharpness
# transforme a tensor  2513
# transforme a sharpness
# transforme a tensor  2514
# transforme a sharpness
# transforme a tensor  2515
# transforme a sharpness
# transforme a tensor  2516
# transforme a sharpness
# transforme a tensor  2517
# transforme a sharpness
# transforme a tensor  2518
# transforme a sharpness
# transforme a tensor  2519
# transforme a sharpness
# transforme a tensor  2520
# transforme a sharpness
# transforme a tensor  2521
# transforme a sharpness
# transforme a tensor  2522
# transforme a sharpness
# transforme a tensor  2523
# transforme a sharpness
# transforme a tensor  2524
# transforme a sharpness
# transforme a tensor  2525
# transforme a sharpness
# transforme a tensor  2526
# transforme a sharpness
# transforme a tensor  2527
# transforme a sharpness
# transforme a tensor  2528
# transforme a sharpness
# transforme a tensor  2529
# transforme a sharpness
# transforme a tensor  2530
# transforme a sharpness
# transforme a tensor  2531
# transforme a sharpness
# transforme a tensor  2532
# transforme a sharpness
# transforme a tensor  2533
# transforme a sharpness
# transforme a tensor  2534
# transforme a sharpness
# transforme a tensor  2535
# transforme a sharpness
# transforme a tensor  2536
# transforme a sharpness
# transforme a tensor  2537
# transforme a sharpness
# transforme a tensor  2538
# transforme a sharpness
# transforme a tensor  2539
# transforme a sharpness
# transforme a tensor  2540
# transforme a sharpness
# transforme a tensor  2541
# transforme a sharpness
# transforme a tensor  2542
# transforme a sharpness
# transforme a tensor  2543
# transforme a sharpness
# transforme a tensor  2544
# transforme a sharpness
# transforme a tensor  2545
# transforme a sharpness
# transforme a tensor  2546
# transforme a sharpness
# transforme a tensor  2547
# transforme a sharpness
# transforme a tensor  2548
# transforme a sharpness
# transforme a tensor  2549
# transforme a sharpness
# transforme a tensor  2550
# transforme a sharpness
# transforme a tensor  2551
# transforme a sharpness
# transforme a tensor  2552
# transforme a sharpness
# transforme a tensor  2553
# transforme a sharpness
# transforme a tensor  2554
# transforme a sharpness
# transforme a tensor  2555
# transforme a sharpness
# transforme a tensor  2556
# transforme a sharpness
# transforme a tensor  2557
# transforme a sharpness
# transforme a tensor  2558
# transforme a sharpness
# transforme a tensor  2559
# transforme a sharpness
# transforme a tensor  2560
# transforme a sharpness
# transforme a tensor  2561
# transforme a sharpness
# transforme a tensor  2562
# transforme a sharpness
# transforme a tensor  2563
# transforme a sharpness
# transforme a tensor  2564
# transforme a sharpness
# transforme a tensor  2565
# transforme a sharpness
# transforme a tensor  2566
# transforme a sharpness
# transforme a tensor  2567
# transforme a sharpness
# transforme a tensor  2568
# transforme a sharpness
# transforme a tensor  2569
# transforme a sharpness
# transforme a tensor  2570
# transforme a sharpness
# transforme a tensor  2571
# transforme a sharpness
# transforme a tensor  2572
# transforme a sharpness
# transforme a tensor  2573
# transforme a sharpness
# transforme a tensor  2574
# transforme a sharpness
# ...
# transforme a sharpness
# transforme a tensor  3771
# transforme a sharpness
# transforme a tensor  3772
# transforme a sharpness
# transforme a tensor  3773
# transforme a sharpness
# transforme a tensor  3774
# transforme a sharpness
# transforme a tensor  3775
# transforme a sharpness
# transforme a tensor  3776
# transforme a sharpness
# transforme a tensor  3777
# transforme a sharpness
# transforme a tensor  3778
# transforme a sharpness
# transforme a tensor  3779
# transforme a sharpness
# transforme a tensor  3780
# transforme a sharpness
# transforme a tensor  3781
# transforme a sharpness
# transforme a tensor  3782
# transforme a sharpness
# transforme a tensor  3783
# transforme a sharpness
# transforme a tensor  3784
# transforme a sharpness
# transforme a tensor  3785
# transforme a sharpness
# transforme a tensor  3786
# transforme a sharpness
# transforme a tensor  3787
# transforme a sharpness
# transforme a tensor  3788
# transforme a sharpness
# transforme a tensor  3789
# transforme a sharpness
# transforme a tensor  3790
# transforme a sharpness
# transforme a tensor  3791
# transforme a sharpness
# transforme a tensor  3792
# transforme a sharpness
# transforme a tensor  3793
# transforme a sharpness
# transforme a tensor  3794
# transforme a sharpness
# transforme a tensor  3795
# transforme a sharpness
# transforme a tensor  3796
# transforme a sharpness
# transforme a tensor  3797
# transforme a sharpness
# transforme a tensor  3798
# transforme a sharpness
# transforme a tensor  3799
# transforme a sharpness
# transforme a tensor  3800
# transforme a sharpness
# transforme a tensor  3801
# transforme a sharpness
# transforme a tensor  3802
# transforme a sharpness
# transforme a tensor  3803
# transforme a sharpness
# transforme a tensor  3804
# transforme a sharpness
# transforme a tensor  3805
# transforme a sharpness
# transforme a tensor  3806
# transforme a sharpness
# transforme a tensor  3807
# transforme a sharpness
# transforme a tensor  3808
# transforme a sharpness
# transforme a tensor  3809
# transforme a sharpness
# transforme a tensor  3810
# transforme a sharpness
# transforme a tensor  3811
# transforme a sharpness
# transforme a tensor  3812
# transforme a sharpness
# transforme a tensor  3813
# transforme a sharpness
# transforme a tensor  3814
# transforme a sharpness
# transforme a tensor  3815
# transforme a sharpness
# transforme a tensor  3816
# transforme a sharpness
# transforme a tensor  3817
# transforme a sharpness
# transforme a tensor  3818
# transforme a sharpness
# transforme a tensor  3819
# transforme a sharpness
# transforme a tensor  3820
# transforme a sharpness
# transforme a tensor  3821
# transforme a sharpness
# transforme a tensor  3822
# transforme a sharpness
# transforme a tensor  3823
# transforme a sharpness
# transforme a tensor  3824
# transforme a sharpness
# transforme a tensor  3825
# transforme a sharpness
# transforme a tensor  3826
# transforme a sharpness
# transforme a tensor  3827
# transforme a sharpness
# transforme a tensor  3828
# transforme a sharpness
# transforme a tensor  3829
# transforme a sharpness
# transforme a tensor  3830
# transforme a sharpness
# transforme a tensor  3831
# transforme a sharpness
# transforme a tensor  3832
# transforme a sharpness
# transforme a tensor  3833
# transforme a sharpness
# transforme a tensor  3834
# transforme a sharpness
# transforme a tensor  3835
# transforme a sharpness
# transforme a tensor  3836
# transforme a sharpness
# transforme a tensor  3837
# transforme a sharpness
# transforme a tensor  3838
# transforme a sharpness
# transforme a tensor  3839
# transforme a sharpness
# transforme a tensor  3840
# transforme a sharpness
# transforme a tensor  3841
# transforme a sharpness
# transforme a tensor  3842
# transforme a sharpness
# transforme a tensor  3843
# transforme a sharpness
# transforme a tensor  3844
# transforme a sharpness
# transforme a tensor  3845
# transforme a sharpness
# transforme a tensor  3846
# transforme a sharpness
# transforme a tensor  3847
# transforme a sharpness
# transforme a tensor  3848
# transforme a sharpness
# transforme a tensor  3849
# transforme a sharpness
# transforme a tensor  3850
# transforme a sharpness
# transforme a tensor  3851
# transforme a sharpness
# transforme a tensor  3852
# transforme a sharpness
# transforme a tensor  3853
# transforme a sharpness
# transforme a tensor  3854
# transforme a sharpness
# transforme a tensor  3855
# transforme a sharpness
# transforme a tensor  3856
# transforme a sharpness
# transforme a tensor  3857
# transforme a sharpness
# transforme a tensor  3858
# transforme a sharpness
# transforme a tensor  3859
# transforme a sharpness
# transforme a tensor  3860
# transforme a sharpness
# transforme a tensor  3861
# transforme a sharpness
# transforme a tensor  3862
# transforme a sharpness
# transforme a tensor  3863
# transforme a sharpness
# transforme a tensor  3864
# transforme a sharpness
# transforme a tensor  3865
# transforme a sharpness
# transforme a tensor  3866
# transforme a sharpness
# transforme a tensor  3867
# transforme a sharpness
# transforme a tensor  3868
# transforme a sharpness
# transforme a tensor  3869
# transforme a sharpness
# transforme a tensor  3870
# transforme a sharpness
# transforme a tensor  3871
# transforme a sharpness
# transforme a tensor  3872
# transforme a sharpness
# transforme a tensor  3873
# transforme a sharpness
# transforme a tensor  3874
# transforme a sharpness
# transforme a tensor  3875
# transforme a sharpness
# transforme a tensor  3876
# transforme a sharpness
# transforme a tensor  3877
# transforme a sharpness
# transforme a tensor  3878
# transforme a sharpness
# transforme a tensor  3879
# transforme a sharpness
# transforme a tensor  3880
# transforme a sharpness
# transforme a tensor  3881
# transforme a sharpness
# transforme a tensor  3882
# transforme a sharpness
# transforme a tensor  3883
# transforme a sharpness
# transforme a tensor  3884
# transforme a sharpness
# transforme a tensor  3885
# transforme a sharpness
# transforme a tensor  3886
# transforme a sharpness
# transforme a tensor  3887
# transforme a sharpness
# transforme a tensor  3888
# transforme a sharpness
# transforme a tensor  3889
# transforme a sharpness
# transforme a tensor  3890
# transforme a sharpness
# transforme a tensor  3891
# transforme a sharpness
# transforme a tensor  3892
# transforme a sharpness
# transforme a tensor  3893
# transforme a sharpness
# transforme a tensor  3894
# transforme a sharpness
# transforme a tensor  3895
# transforme a sharpness
# transforme a tensor  3896
# transforme a sharpness
# transforme a tensor  3897
# transforme a sharpness
# transforme a tensor  3898
# transforme a sharpness
# transforme a tensor  3899
# transforme a sharpness
# transforme a tensor  3900
# transforme a sharpness
# transforme a tensor  3901
# transforme a sharpness
# transforme a tensor  3902
# transforme a sharpness
# transforme a tensor  3903
# transforme a sharpness
# transforme a tensor  3904
# transforme a sharpness
# transforme a tensor  3905
# transforme a sharpness
# transforme a tensor  3906
# transforme a sharpness
# transforme a tensor  3907
# transforme a sharpness
# transforme a tensor  3908
# transforme a sharpness
# transforme a tensor  3909
# transforme a sharpness
# transforme a tensor  3910
# transforme a sharpness
# transforme a tensor  3911
# transforme a sharpness
# transforme a tensor  3912
# transforme a sharpness
# transforme a tensor  3913
# transforme a sharpness
# transforme a tensor  3914
# transforme a sharpness
# transforme a tensor  3915
# transforme a sharpness
# transforme a tensor  3916
# transforme a sharpness
# transforme a tensor  3917
# transforme a sharpness
# transforme a tensor  3918
# transforme a sharpness
# transforme a tensor  3919
# transforme a sharpness
# transforme a tensor  3920
# transforme a sharpness
# transforme a tensor  3921
# transforme a sharpness
# transforme a tensor  3922
# transforme a sharpness
# transforme a tensor  3923
# transforme a sharpness
# transforme a tensor  3924
# transforme a sharpness
# transforme a tensor  3925
# transforme a sharpness
# transforme a tensor  3926
# transforme a sharpness
# transforme a tensor  3927
# transforme a sharpness
# transforme a tensor  3928
# transforme a sharpness
# transforme a tensor  3929
# transforme a sharpness
# transforme a tensor  3930
# transforme a sharpness
# transforme a tensor  3931
# transforme a sharpness
# transforme a tensor  3932
# transforme a sharpness
# transforme a tensor  3933
# transforme a sharpness
# transforme a tensor  3934
# transforme a sharpness
# transforme a tensor  3935
# transforme a sharpness
# transforme a tensor  3936
# transforme a sharpness
# transforme a tensor  3937
# transforme a sharpness
# transforme a tensor  3938
# transforme a sharpness
# transforme a tensor  3939
# transforme a sharpness
# transforme a tensor  3940
# transforme a sharpness
# transforme a tensor  3941
# transforme a sharpness
# transforme a tensor  3942
# transforme a sharpness
# transforme a tensor  3943
# transforme a sharpness
# transforme a tensor  3944
# transforme a sharpness
# transforme a tensor  3945
# transforme a sharpness
# transforme a tensor  3946
# transforme a sharpness
# transforme a tensor  3947
# transforme a sharpness
# transforme a tensor  3948
# transforme a sharpness
# transforme a tensor  3949
# transforme a sharpness
# transforme a tensor  3950
# transforme a sharpness
# transforme a tensor  3951
# transforme a sharpness
# transforme a tensor  3952
# transforme a sharpness
# transforme a tensor  3953
# transforme a sharpness
# transforme a tensor  3954
# transforme a sharpness
# transforme a tensor  3955
# transforme a sharpness
# transforme a tensor  3956
# transforme a sharpness
# transforme a tensor  3957
# transforme a sharpness
# transforme a tensor  3958
# transforme a sharpness
# transforme a tensor  3959
# transforme a sharpness
# transforme a tensor  3960
# transforme a sharpness
# transforme a tensor  3961
# transforme a sharpness
# transforme a tensor  3962
# transforme a sharpness
# transforme a tensor  3963
# transforme a sharpness
# transforme a tensor  3964
# transforme a sharpness
# transforme a tensor  3965
# transforme a sharpness
# transforme a tensor  3966
# transforme a sharpness
# transforme a tensor  3967
# transforme a sharpness
# transforme a tensor  3968
# transforme a sharpness
# transforme a tensor  3969
# transforme a sharpness
# transforme a tensor  3970
# transforme a sharpness
# transforme a tensor  3971
# transforme a sharpness
# transforme a tensor  3972
# transforme a sharpness
# transforme a tensor  3973
# transforme a sharpness
# transforme a tensor  3974
# transforme a sharpness
# transforme a tensor  3975
# transforme a sharpness
# transforme a tensor  3976
# transforme a sharpness
# transforme a tensor  3977
# transforme a sharpness
# transforme a tensor  3978
# transforme a sharpness
# transforme a tensor  3979
# transforme a sharpness
# transforme a tensor  3980
# transforme a sharpness
# transforme a tensor  3981
# transforme a sharpness
# transforme a tensor  3982
# transforme a sharpness
# transforme a tensor  3983
# transforme a sharpness
# transforme a tensor  3984
# transforme a sharpness
# transforme a tensor  3985
# transforme a sharpness
# transforme a tensor  3986
# transforme a sharpness
# transforme a tensor  3987
# transforme a sharpness
# transforme a tensor  3988
# transforme a sharpness
# transforme a tensor  3989
# transforme a sharpness
# transforme a tensor  3990
# transforme a sharpness
# transforme a tensor  3991
# transforme a sharpness
# transforme a tensor  3992
# transforme a sharpness
# transforme a tensor  3993
# transforme a sharpness
# transforme a tensor  3994
# transforme a sharpness
# transforme a tensor  3995
# transforme a sharpness
# transforme a tensor  3996
# transforme a sharpness
# transforme a tensor  3997
# transforme a sharpness
# transforme a tensor  3998
# transforme a sharpness
# transforme a tensor  3999
# transforme a sharpness
# transforme a tensor  4000
# transforme a sharpness
# transforme a tensor  4001
# transforme a sharpness
# transforme a tensor  4002
# transforme a sharpness
# transforme a tensor  4003
# transforme a sharpness
# transforme a tensor  4004
# transforme a sharpness
# transforme a tensor  4005
# transforme a sharpness
# transforme a tensor  4006
# transforme a sharpness
# transforme a tensor  4007
# transforme a sharpness
# transforme a tensor  4008
# transforme a sharpness
# transforme a tensor  4009
# transforme a sharpness
# transforme a tensor  4010
# transforme a sharpness
# transforme a tensor  4011
# transforme a sharpness
# transforme a tensor  4012
# transforme a sharpness
# transforme a tensor  4013
# transforme a sharpness
# transforme a tensor  4014
# transforme a sharpness
# transforme a tensor  4015
# transforme a sharpness
# transforme a tensor  4016
# transforme a sharpness
# transforme a tensor  4017
# transforme a sharpness
# transforme a tensor  4018
# transforme a sharpness
# transforme a tensor  4019
# transforme a sharpness
# transforme a tensor  4020
# transforme a sharpness
# transforme a tensor  4021
# transforme a sharpness
# transforme a tensor  4022
# transforme a sharpness
# transforme a tensor  4023
# transforme a sharpness
# transforme a tensor  4024
# transforme a sharpness
# transforme a tensor  4025
# transforme a sharpness
# transforme a tensor  4026
# transforme a sharpness
# transforme a tensor  4027
# transforme a sharpness
# transforme a tensor  4028
# transforme a sharpness
# transforme a tensor  4029
# transforme a sharpness
# transforme a tensor  4030
# transforme a sharpness
# transforme a tensor  4031
# transforme a sharpness
# transforme a tensor  4032
# transforme a sharpness
# transforme a tensor  4033
# transforme a sharpness
# transforme a tensor  4034
# transforme a sharpness
# transforme a tensor  4035
# transforme a sharpness
# transforme a tensor  4036
# transforme a sharpness
# transforme a tensor  4037
# transforme a sharpness
# transforme a tensor  4038
# transforme a sharpness
# transforme a tensor  4039
# transforme a sharpness
# transforme a tensor  4040
# transforme a sharpness
# transforme a tensor  4041
# transforme a sharpness
# transforme a tensor  4042
# transforme a sharpness
# transforme a tensor  4043
# transforme a sharpness
# transforme a tensor  4044
# transforme a sharpness
# transforme a tensor  4045
# transforme a sharpness
# transforme a tensor  4046
# transforme a sharpness
# transforme a tensor  4047
# transforme a sharpness
# transforme a tensor  4048
# transforme a sharpness
# transforme a tensor  4049
# transforme a sharpness
# transforme a tensor  4050
# transforme a sharpness
# transforme a tensor  4051
# transforme a sharpness
# transforme a tensor  4052
# transforme a sharpness
# transforme a tensor  4053
# transforme a sharpness
# transforme a tensor  4054
# transforme a sharpness
# transforme a tensor  4055
# transforme a sharpness
# transforme a tensor  4056
# transforme a sharpness
# transforme a tensor  4057
# transforme a sharpness
# transforme a tensor  4058
# transforme a sharpness
# transforme a tensor  4059
# transforme a sharpness
# transforme a tensor  4060
# transforme a sharpness
# transforme a tensor  4061
# transforme a sharpness
# transforme a tensor  4062
# transforme a sharpness
# transforme a tensor  4063
# transforme a sharpness
# transforme a tensor  4064
# transforme a sharpness
# transforme a tensor  4065
# transforme a sharpness
# transforme a tensor  4066
# transforme a sharpness
# transforme a tensor  4067
# transforme a sharpness
# transforme a tensor  4068
# transforme a sharpness
# transforme a tensor  4069
# transforme a sharpness
# transforme a tensor  4070
# transforme a sharpness
# transforme a tensor  4071
# transforme a sharpness
# transforme a tensor  4072
# transforme a sharpness
# transforme a tensor  4073
# transforme a sharpness
# transforme a tensor  4074
# transforme a sharpness
# transforme a tensor  4075
# transforme a sharpness
# transforme a tensor  4076
# transforme a sharpness
# transforme a tensor  4077
# transforme a sharpness
# transforme a tensor  4078
# transforme a sharpness
# transforme a tensor  4079
# transforme a sharpness
# transforme a tensor  4080
# transforme a sharpness
# transforme a tensor  4081
# transforme a sharpness
# transforme a tensor  4082
# transforme a sharpness
# transforme a tensor  4083
# transforme a sharpness
# transforme a tensor  4084
# transforme a sharpness
# transforme a tensor  4085
# transforme a sharpness
# transforme a tensor  4086
# transforme a sharpness
# transforme a tensor  4087
# transforme a sharpness
# transforme a tensor  4088
# transforme a sharpness
# transforme a tensor  4089
# transforme a sharpness
# transforme a tensor  4090
# transforme a sharpness
# transforme a tensor  4091
# transforme a sharpness
# transforme a tensor  4092
# transforme a sharpness
# transforme a tensor  4093
# transforme a sharpness
# transforme a tensor  4094
# transforme a sharpness
# transforme a tensor  4095
# transforme a sharpness
# transforme a tensor  4096
# transforme a sharpness

# %%
dataset_val = MRIDataset(val_data2)
dataloader_val = DataLoader(dataset_val, batch_size = batch_size, shuffle=True)
# Out:
# transforme a tensor  1
# transforme a sharpness
# transforme a tensor  2
# transforme a sharpness
# transforme a tensor  3
# transforme a sharpness
# transforme a tensor  4
# transforme a sharpness
# transforme a tensor  5
# transforme a sharpness
# transforme a tensor  6
# transforme a sharpness
# transforme a tensor  7
# transforme a sharpness
# transforme a tensor  8
# transforme a sharpness
# transforme a tensor  9
# transforme a sharpness
# transforme a tensor  10
# transforme a sharpness
# transforme a tensor  11
# transforme a sharpness
# transforme a tensor  12
# transforme a sharpness
# transforme a tensor  13
# transforme a sharpness
# transforme a tensor  14
# transforme a sharpness
# transforme a tensor  15
# transforme a sharpness
# transforme a tensor  16
# transforme a sharpness
# transforme a tensor  17
# transforme a sharpness
# transforme a tensor  18
# transforme a sharpness
# transforme a tensor  19
# transforme a sharpness
# transforme a tensor  20
# transforme a sharpness
# transforme a tensor  21
# transforme a sharpness
# transforme a tensor  22
# transforme a sharpness
# transforme a tensor  23
# transforme a sharpness
# transforme a tensor  24
# transforme a sharpness
# transforme a tensor  25
# transforme a sharpness
# transforme a tensor  26
# transforme a sharpness
# transforme a tensor  27
# transforme a sharpness
# transforme a tensor  28
# transforme a sharpness
# transforme a tensor  29
# transforme a sharpness
# transforme a tensor  30
# transforme a sharpness
# transforme a tensor  31
# transforme a sharpness
# transforme a tensor  32
# transforme a sharpness
# transforme a tensor  33
# transforme a sharpness
# transforme a tensor  34
# transforme a sharpness
# transforme a tensor  35
# transforme a sharpness
# transforme a tensor  36
# transforme a sharpness
# transforme a tensor  37
# transforme a sharpness
# transforme a tensor  38
# transforme a sharpness
# transforme a tensor  39
# transforme a sharpness
# transforme a tensor  40
# transforme a sharpness
# transforme a tensor  41
# transforme a sharpness
# transforme a tensor  42
# transforme a sharpness
# transforme a tensor  43
# transforme a sharpness
# transforme a tensor  44
# transforme a sharpness
# transforme a tensor  45
# transforme a sharpness
# transforme a tensor  46
# transforme a sharpness
# transforme a tensor  47
# transforme a sharpness
# transforme a tensor  48
# transforme a sharpness
# transforme a tensor  49
# transforme a sharpness
# transforme a tensor  50
# transforme a sharpness
# transforme a tensor  51
# transforme a sharpness
# transforme a tensor  52
# transforme a sharpness
# transforme a tensor  53
# transforme a sharpness
# transforme a tensor  54
# transforme a sharpness
# transforme a tensor  55
# transforme a sharpness
# transforme a tensor  56
# transforme a sharpness
# transforme a tensor  57
# transforme a sharpness
# transforme a tensor  58
# transforme a sharpness
# transforme a tensor  59
# transforme a sharpness
# transforme a tensor  60
# transforme a sharpness
# transforme a tensor  61
# transforme a sharpness
# transforme a tensor  62
# transforme a sharpness
# transforme a tensor  63
# transforme a sharpness
# transforme a tensor  64
# transforme a sharpness
# transforme a tensor  65
# transforme a sharpness
# transforme a tensor  66
# transforme a sharpness
# transforme a tensor  67
# transforme a sharpness
# transforme a tensor  68
# transforme a sharpness
# transforme a tensor  69
# transforme a sharpness
# transforme a tensor  70
# transforme a sharpness
# transforme a tensor  71
# transforme a sharpness
# transforme a tensor  72
# transforme a sharpness
# transforme a tensor  73
# transforme a sharpness
# transforme a tensor  74
# transforme a sharpness
# transforme a tensor  75
# transforme a sharpness
# transforme a tensor  76
# transforme a sharpness
# transforme a tensor  77
# transforme a sharpness
# transforme a tensor  78
# transforme a sharpness
# transforme a tensor  79
# transforme a sharpness
# transforme a tensor  80
# transforme a sharpness
# transforme a tensor  81
# transforme a sharpness
# transforme a tensor  82
# transforme a sharpness
# transforme a tensor  83
# transforme a sharpness
# transforme a tensor  84
# transforme a sharpness
# transforme a tensor  85
# transforme a sharpness
# transforme a tensor  86
# transforme a sharpness
# transforme a tensor  87
# transforme a sharpness
# transforme a tensor  88
# transforme a sharpness
# transforme a tensor  89
# transforme a sharpness
# transforme a tensor  90
# transforme a sharpness
# transforme a tensor  91
# transforme a sharpness
# transforme a tensor  92
# transforme a sharpness
# transforme a tensor  93
# transforme a sharpness
# transforme a tensor  94
# transforme a sharpness
# transforme a tensor  95
# transforme a sharpness
# transforme a tensor  96
# transforme a sharpness
# transforme a tensor  97
# transforme a sharpness
# transforme a tensor  98
# transforme a sharpness
# transforme a tensor  99
# transforme a sharpness
# transforme a tensor  100
# transforme a sharpness
# transforme a tensor  101
# transforme a sharpness
# transforme a tensor  102
# transforme a sharpness
# transforme a tensor  103
# transforme a sharpness
# transforme a tensor  104
# transforme a sharpness
# transforme a tensor  105
# transforme a sharpness
# transforme a tensor  106
# transforme a sharpness
# transforme a tensor  107
# transforme a sharpness
# transforme a tensor  108
# transforme a sharpness
# transforme a tensor  109
# transforme a sharpness
# transforme a tensor  110
# transforme a sharpness
# transforme a tensor  111
# transforme a sharpness
# transforme a tensor  112
# transforme a sharpness
# transforme a tensor  113
# transforme a sharpness
# transforme a tensor  114
# transforme a sharpness
# transforme a tensor  115
# transforme a sharpness
# transforme a tensor  116
# transforme a sharpness
# transforme a tensor  117
# transforme a sharpness
# transforme a tensor  118
# transforme a sharpness
# transforme a tensor  119
# transforme a sharpness
# transforme a tensor  120
# transforme a sharpness
# transforme a tensor  121
# transforme a sharpness
# transforme a tensor  122
# transforme a sharpness
# transforme a tensor  123
# transforme a sharpness
# transforme a tensor  124
# transforme a sharpness
# transforme a tensor  125
# transforme a sharpness
# transforme a tensor  126
# transforme a sharpness
# transforme a tensor  127
# transforme a sharpness
# transforme a tensor  128
# transforme a sharpness
# transforme a tensor  129
# transforme a sharpness
# transforme a tensor  130
# transforme a sharpness
# transforme a tensor  131
# transforme a sharpness
# transforme a tensor  132
# transforme a sharpness
# transforme a tensor  133
# transforme a sharpness
# transforme a tensor  134
# transforme a sharpness
# transforme a tensor  135
# transforme a sharpness
# transforme a tensor  136
# transforme a sharpness
# transforme a tensor  137
# transforme a sharpness
# transforme a tensor  138
# transforme a sharpness
# transforme a tensor  139
# transforme a sharpness
# transforme a tensor  140
# transforme a sharpness
# transforme a tensor  141
# transforme a sharpness
# transforme a tensor  142
# transforme a sharpness
# transforme a tensor  143
# transforme a sharpness
# transforme a tensor  144
# transforme a sharpness
# transforme a tensor  145
# transforme a sharpness
# transforme a tensor  146
# transforme a sharpness
# transforme a tensor  147
# transforme a sharpness
# transforme a tensor  148
# transforme a sharpness
# transforme a tensor  149
# transforme a sharpness
# transforme a tensor  150
# transforme a sharpness
# transforme a tensor  151
# transforme a sharpness
# transforme a tensor  152
# transforme a sharpness
# transforme a tensor  153
# transforme a sharpness
# transforme a tensor  154
# transforme a sharpness
# transforme a tensor  155
# transforme a sharpness
# transforme a tensor  156
# transforme a sharpness
# transforme a tensor  157
# transforme a sharpness
# transforme a tensor  158
# transforme a sharpness
# transforme a tensor  159
# transforme a sharpness
# transforme a tensor  160
# transforme a sharpness
# transforme a tensor  161
# transforme a sharpness
# transforme a tensor  162
# transforme a sharpness
# transforme a tensor  163
# transforme a sharpness
# transforme a tensor  164
# transforme a sharpness
# transforme a tensor  165
# transforme a sharpness
# transforme a tensor  166
# transforme a sharpness
# transforme a tensor  167
# transforme a sharpness
# transforme a tensor  168
# transforme a sharpness
# transforme a tensor  169
# transforme a sharpness
# transforme a tensor  170
# transforme a sharpness
# transforme a tensor  171
# transforme a sharpness
# transforme a tensor  172
# transforme a sharpness
# transforme a tensor  173
# transforme a sharpness
# transforme a tensor  174
# transforme a sharpness
# transforme a tensor  175
# transforme a sharpness
# transforme a tensor  176
# transforme a sharpness
# transforme a tensor  177
# transforme a sharpness
# transforme a tensor  178
# transforme a sharpness
# transforme a tensor  179
# transforme a sharpness
# transforme a tensor  180
# transforme a sharpness
# transforme a tensor  181
# transforme a sharpness
# transforme a tensor  182
# transforme a sharpness
# transforme a tensor  183
# transforme a sharpness
# transforme a tensor  184
# transforme a sharpness
# transforme a tensor  185
# transforme a sharpness
# transforme a tensor  186
# transforme a sharpness
# transforme a tensor  187
# transforme a sharpness
# transforme a tensor  188
# transforme a sharpness
# transforme a tensor  189
# transforme a sharpness
# transforme a tensor  190
# transforme a sharpness
# transforme a tensor  191
# transforme a sharpness
# transforme a tensor  192
# transforme a sharpness
# transforme a tensor  193
# transforme a sharpness
# transforme a tensor  194
# transforme a sharpness
# transforme a tensor  195
# transforme a sharpness
# transforme a tensor  196
# transforme a sharpness
# transforme a tensor  197
# transforme a sharpness
# transforme a tensor  198
# transforme a sharpness
# transforme a tensor  199
# transforme a sharpness
# transforme a tensor  200
# transforme a sharpness
# transforme a tensor  201
# transforme a sharpness
# transforme a tensor  202
# transforme a sharpness
# transforme a tensor  203
# transforme a sharpness
# transforme a tensor  204
# transforme a sharpness
# transforme a tensor  205
# transforme a sharpness
# transforme a tensor  206
# transforme a sharpness
# transforme a tensor  207
# transforme a sharpness
# transforme a tensor  208
# transforme a sharpness
# transforme a tensor  209
# transforme a sharpness
# transforme a tensor  210
# transforme a sharpness
# transforme a tensor  211
# transforme a sharpness
# transforme a tensor  212
# transforme a sharpness
# transforme a tensor  213
# transforme a sharpness
# transforme a tensor  214
# transforme a sharpness
# transforme a tensor  215
# transforme a sharpness
# transforme a tensor  216
# transforme a sharpness
# transforme a tensor  217
# transforme a sharpness
# transforme a tensor  218
# transforme a sharpness
# transforme a tensor  219
# transforme a sharpness
# transforme a tensor  220
# transforme a sharpness
# transforme a tensor  221
# transforme a sharpness
# transforme a tensor  222
# transforme a sharpness
# transforme a tensor  223
# transforme a sharpness
# transforme a tensor  224
# transforme a sharpness
# transforme a tensor  225
# transforme a sharpness
# transforme a tensor  226
# transforme a sharpness
# transforme a tensor  227
# transforme a sharpness
# transforme a tensor  228
# transforme a sharpness
# transforme a tensor  229
# transforme a sharpness
# transforme a tensor  230
# transforme a sharpness
# transforme a tensor  231
# transforme a sharpness
# transforme a tensor  232
# transforme a sharpness
# transforme a tensor  233
# transforme a sharpness
# transforme a tensor  234
# transforme a sharpness
# transforme a tensor  235
# transforme a sharpness
# transforme a tensor  236
# transforme a sharpness
# transforme a tensor  237
# transforme a sharpness
# transforme a tensor  238
# transforme a sharpness
# transforme a tensor  239
# transforme a sharpness
# transforme a tensor  240
# transforme a sharpness
# transforme a tensor  241
# transforme a sharpness
# transforme a tensor  242
# transforme a sharpness
# transforme a tensor  243
# transforme a sharpness
# transforme a tensor  244
# transforme a sharpness
# transforme a tensor  245
# transforme a sharpness
# transforme a tensor  246
# transforme a sharpness
# transforme a tensor  247
# transforme a sharpness
# transforme a tensor  248
# transforme a sharpness
# transforme a tensor  249
# transforme a sharpness
# transforme a tensor  250
# transforme a sharpness
# transforme a tensor  251
# transforme a sharpness
# transforme a tensor  252
# transforme a sharpness
# transforme a tensor  253
# transforme a sharpness
# transforme a tensor  254
# transforme a sharpness
# transforme a tensor  255
# transforme a sharpness
# transforme a tensor  256
# transforme a sharpness
# transforme a tensor  257
# transforme a sharpness
# transforme a tensor  258
# transforme a sharpness
# transforme a tensor  259
# transforme a sharpness
# transforme a tensor  260
# transforme a sharpness
# transforme a tensor  261
# transforme a sharpness
# transforme a tensor  262
# transforme a sharpness
# transforme a tensor  263
# transforme a sharpness
# transforme a tensor  264
# transforme a sharpness
# transforme a tensor  265
# transforme a sharpness
# transforme a tensor  266
# transforme a sharpness
# transforme a tensor  267
# transforme a sharpness
# transforme a tensor  268
# transforme a sharpness
# transforme a tensor  269
# transforme a sharpness
# transforme a tensor  270
# transforme a sharpness
# transforme a tensor  271
# transforme a sharpness
# transforme a tensor  272
# transforme a sharpness
# transforme a tensor  273
# transforme a sharpness
# transforme a tensor  274
# transforme a sharpness
# transforme a tensor  275
# transforme a sharpness
# transforme a tensor  276
# transforme a sharpness
# transforme a tensor  277
# transforme a sharpness
# transforme a tensor  278
# transforme a sharpness
# transforme a tensor  279
# transforme a sharpness
# transforme a tensor  280
# transforme a sharpness
# transforme a tensor  281
# transforme a sharpness
# transforme a tensor  282
# transforme a sharpness
# transforme a tensor  283
# transforme a sharpness
# transforme a tensor  284
# transforme a sharpness
# transforme a tensor  285
# transforme a sharpness
# transforme a tensor  286
# transforme a sharpness
# transforme a tensor  287
# transforme a sharpness
# transforme a tensor  288
# transforme a sharpness
# transforme a tensor  289
# transforme a sharpness
# transforme a tensor  290
# transforme a sharpness
# transforme a tensor  291
# transforme a sharpness
# transforme a tensor  292
# transforme a sharpness
# transforme a tensor  293
# transforme a sharpness
# transforme a tensor  294
# transforme a sharpness
# transforme a tensor  295
# transforme a sharpness
# transforme a tensor  296
# transforme a sharpness
# transforme a tensor  297
# transforme a sharpness
# transforme a tensor  298
# transforme a sharpness
# transforme a tensor  299
# transforme a sharpness
# transforme a tensor  300
# transforme a sharpness
# transforme a tensor  301
# transforme a sharpness
# transforme a tensor  302
# transforme a sharpness
# transforme a tensor  303
# transforme a sharpness
# transforme a tensor  304
# transforme a sharpness
# transforme a tensor  305
# transforme a sharpness
# transforme a tensor  306
# transforme a sharpness
# transforme a tensor  307
# transforme a sharpness
# transforme a tensor  308
# transforme a sharpness
# transforme a tensor  309
# transforme a sharpness
# transforme a tensor  310
# transforme a sharpness
# transforme a tensor  311
# transforme a sharpness
# transforme a tensor  312
# transforme a sharpness
# transforme a tensor  313
# transforme a sharpness
# transforme a tensor  314
# transforme a sharpness
# transforme a tensor  315
# transforme a sharpness
# transforme a tensor  316
# transforme a sharpness
# transforme a tensor  317
# transforme a sharpness
# transforme a tensor  318
# transforme a sharpness
# transforme a tensor  319
# transforme a sharpness
# transforme a tensor  320
# transforme a sharpness
# transforme a tensor  321
# transforme a sharpness
# transforme a tensor  322
# transforme a sharpness
# transforme a tensor  323
# transforme a sharpness
# transforme a tensor  324
# transforme a sharpness
# transforme a tensor  325
# transforme a sharpness
# transforme a tensor  326
# transforme a sharpness
# transforme a tensor  327
# transforme a sharpness
# transforme a tensor  328
# transforme a sharpness
# transforme a tensor  329
# transforme a sharpness
# transforme a tensor  330
# transforme a sharpness
# transforme a tensor  331
# transforme a sharpness
# transforme a tensor  332
# transforme a sharpness
# transforme a tensor  333
# transforme a sharpness
# transforme a tensor  334
# transforme a sharpness
# transforme a tensor  335
# transforme a sharpness
# transforme a tensor  336
# transforme a sharpness
# transforme a tensor  337
# transforme a sharpness
# transforme a tensor  338
# transforme a sharpness
# transforme a tensor  339
# transforme a sharpness
# transforme a tensor  340
# transforme a sharpness
# transforme a tensor  341
# transforme a sharpness
# transforme a tensor  342
# transforme a sharpness
# transforme a tensor  343
# transforme a sharpness
# transforme a tensor  344
# transforme a sharpness
# transforme a tensor  345
# transforme a sharpness
# transforme a tensor  346
# transforme a sharpness
# transforme a tensor  347
# transforme a sharpness
# transforme a tensor  348
# transforme a sharpness
# transforme a tensor  349
# transforme a sharpness
# transforme a tensor  350
# transforme a sharpness
# transforme a tensor  351
# transforme a sharpness
# transforme a tensor  352
# transforme a sharpness
# transforme a tensor  353
# transforme a sharpness
# transforme a tensor  354
# transforme a sharpness
# transforme a tensor  355
# transforme a sharpness
# transforme a tensor  356
# transforme a sharpness
# transforme a tensor  357
# transforme a sharpness
# transforme a tensor  358
# transforme a sharpness
# transforme a tensor  359
# transforme a sharpness
# transforme a tensor  360
# transforme a sharpness
# transforme a tensor  361
# transforme a sharpness
# transforme a tensor  362
# transforme a sharpness
# transforme a tensor  363
# transforme a sharpness
# transforme a tensor  364
# transforme a sharpness
# transforme a tensor  365
# transforme a sharpness
# transforme a tensor  366
# transforme a sharpness
# transforme a tensor  367
# transforme a sharpness
# transforme a tensor  368
# transforme a sharpness
# transforme a tensor  369
# transforme a sharpness
# transforme a tensor  370
# transforme a sharpness
# transforme a tensor  371
# transforme a sharpness
# transforme a tensor  372
# transforme a sharpness
# transforme a tensor  373
# transforme a sharpness
# transforme a tensor  374
# transforme a sharpness
# transforme a tensor  375
# transforme a sharpness
# transforme a tensor  376
# transforme a sharpness
# transforme a tensor  377
# transforme a sharpness
# transforme a tensor  378
# transforme a sharpness
# transforme a tensor  379
# transforme a sharpness
# transforme a tensor  380
# transforme a sharpness
# transforme a tensor  381
# transforme a sharpness
# transforme a tensor  382
# transforme a sharpness
# transforme a tensor  383
# transforme a sharpness
# transforme a tensor  384
# transforme a sharpness
# transforme a tensor  385
# transforme a sharpness
# transforme a tensor  386
# transforme a sharpness
# transforme a tensor  387
# transforme a sharpness
# transforme a tensor  388
# transforme a sharpness
# transforme a tensor  389
# transforme a sharpness
# transforme a tensor  390
# transforme a sharpness
# transforme a tensor  391
# transforme a sharpness
# transforme a tensor  392
# transforme a sharpness
# transforme a tensor  393
# transforme a sharpness
# transforme a tensor  394
# transforme a sharpness
# transforme a tensor  395
# transforme a sharpness
# transforme a tensor  396
# transforme a sharpness
# transforme a tensor  397
# transforme a sharpness
# transforme a tensor  398
# transforme a sharpness
# transforme a tensor  399
# transforme a sharpness
# transforme a tensor  400
# transforme a sharpness
# transforme a tensor  401
# transforme a sharpness
# transforme a tensor  402
# transforme a sharpness
# transforme a tensor  403
# transforme a sharpness
# transforme a tensor  404
# transforme a sharpness
# transforme a tensor  405
# transforme a sharpness
# transforme a tensor  406
# transforme a sharpness
# transforme a tensor  407
# transforme a sharpness
# transforme a tensor  408
# transforme a sharpness
# transforme a tensor  409
# transforme a sharpness
# transforme a tensor  410
# transforme a sharpness
# transforme a tensor  411
# transforme a sharpness
# transforme a tensor  412
# transforme a sharpness
# transforme a tensor  413
# transforme a sharpness
# transforme a tensor  414
# transforme a sharpness
# transforme a tensor  415
# transforme a sharpness
# transforme a tensor  416
# transforme a sharpness
# transforme a tensor  417
# transforme a sharpness
# transforme a tensor  418
# transforme a sharpness
# transforme a tensor  419
# transforme a sharpness
# transforme a tensor  420
# transforme a sharpness
# transforme a tensor  421
# transforme a sharpness
# transforme a tensor  422
# transforme a sharpness
# transforme a tensor  423
# transforme a sharpness
# transforme a tensor  424
# transforme a sharpness
# transforme a tensor  425
# transforme a sharpness
# transforme a tensor  426
# transforme a sharpness
# transforme a tensor  427
# transforme a sharpness
# transforme a tensor  428
# transforme a sharpness
# transforme a tensor  429
# transforme a sharpness
# transforme a tensor  430
# transforme a sharpness
# transforme a tensor  431
# transforme a sharpness
# transforme a tensor  432
# transforme a sharpness
# transforme a tensor  433
# transforme a sharpness
# transforme a tensor  434
# transforme a sharpness
# transforme a tensor  435
# transforme a sharpness
# transforme a tensor  436
# transforme a sharpness
# transforme a tensor  437
# transforme a sharpness
# transforme a tensor  438
# transforme a sharpness
# transforme a tensor  439
# transforme a sharpness
# transforme a tensor  440
# transforme a sharpness
# transforme a tensor  441
# transforme a sharpness
# transforme a tensor  442
# transforme a sharpness
# transforme a tensor  443
# transforme a sharpness
# transforme a tensor  444
# transforme a sharpness
# transforme a tensor  445
# transforme a sharpness
# transforme a tensor  446
# transforme a sharpness
# transforme a tensor  447
# transforme a sharpness
# transforme a tensor  448
# transforme a sharpness
# transforme a tensor  449
# transforme a sharpness
# transforme a tensor  450
# transforme a sharpness
# transforme a tensor  451
# transforme a sharpness
# transforme a tensor  452
# transforme a sharpness
# transforme a tensor  453
# transforme a sharpness
# transforme a tensor  454
# transforme a sharpness
# transforme a tensor  455
# transforme a sharpness
# transforme a tensor  456
# transforme a sharpness
# transforme a tensor  457
# transforme a sharpness
# transforme a tensor  458
# transforme a sharpness
# transforme a tensor  459
# transforme a sharpness
# transforme a tensor  460
# transforme a sharpness
# transforme a tensor  461
# transforme a sharpness
# transforme a tensor  462
# transforme a sharpness
# transforme a tensor  463
# transforme a sharpness
# transforme a tensor  464
# transforme a sharpness
# transforme a tensor  465
# transforme a sharpness
# transforme a tensor  466
# transforme a sharpness
# transforme a tensor  467
# transforme a sharpness
# transforme a tensor  468
# transforme a sharpness
# transforme a tensor  469
# transforme a sharpness
# transforme a tensor  470
# transforme a sharpness
# transforme a tensor  471
# transforme a sharpness
# transforme a tensor  472
# transforme a sharpness
# transforme a tensor  473
# transforme a sharpness
# transforme a tensor  474
# transforme a sharpness
# transforme a tensor  475
# transforme a sharpness
# transforme a tensor  476
# transforme a sharpness
# transforme a tensor  477
# transforme a sharpness
# transforme a tensor  478
# transforme a sharpness
# transforme a tensor  479
# transforme a sharpness
# transforme a tensor  480
# transforme a sharpness
# transforme a tensor  481
# transforme a sharpness
# transforme a tensor  482
# transforme a sharpness
# transforme a tensor  483
# transforme a sharpness
# transforme a tensor  484
# transforme a sharpness
# transforme a tensor  485
# transforme a sharpness
# transforme a tensor  486
# transforme a sharpness
# transforme a tensor  487
# transforme a sharpness
# transforme a tensor  488
# transforme a sharpness
# transforme a tensor  489
# transforme a sharpness
# transforme a tensor  490
# transforme a sharpness
# transforme a tensor  491
# transforme a sharpness
# transforme a tensor  492
# transforme a sharpness
# transforme a tensor  493
# transforme a sharpness
# transforme a tensor  494
# transforme a sharpness
# transforme a tensor  495
# transforme a sharpness
# transforme a tensor  496
# transforme a sharpness
# transforme a tensor  497
# transforme a sharpness
# transforme a tensor  498
# transforme a sharpness
# transforme a tensor  499
# transforme a sharpness
# transforme a tensor  500
# transforme a sharpness
# transforme a tensor  501
# transforme a sharpness
# transforme a tensor  502
# transforme a sharpness
# transforme a tensor  503
# transforme a sharpness
# transforme a tensor  504
# transforme a sharpness
# transforme a tensor  505
# transforme a sharpness
# transforme a tensor  506
# transforme a sharpness
# transforme a tensor  507
# transforme a sharpness
# transforme a tensor  508
# transforme a sharpness
# transforme a tensor  509
# transforme a sharpness
# transforme a tensor  510
# transforme a sharpness
# transforme a tensor  511
# transforme a sharpness
# transforme a tensor  512
# transforme a sharpness
# transforme a tensor  513
# transforme a sharpness
# transforme a tensor  514
# transforme a sharpness
# transforme a tensor  515
# transforme a sharpness
# transforme a tensor  516
# transforme a sharpness
# transforme a tensor  517
# transforme a sharpness
# transforme a tensor  518
# transforme a sharpness
# transforme a tensor  519
# transforme a sharpness
# transforme a tensor  520
# transforme a sharpness
# transforme a tensor  521
# transforme a sharpness
# transforme a tensor  522
# transforme a sharpness
# transforme a tensor  523
# transforme a sharpness
# transforme a tensor  524
# transforme a sharpness
# transforme a tensor  525
# transforme a sharpness
# transforme a tensor  526
# transforme a sharpness
# transforme a tensor  527
# transforme a sharpness
# transforme a tensor  528
# transforme a sharpness
# transforme a tensor  529
# transforme a sharpness
# transforme a tensor  530
# transforme a sharpness
# transforme a tensor  531
# transforme a sharpness
# transforme a tensor  532
# transforme a sharpness
# transforme a tensor  533
# transforme a sharpness
# transforme a tensor  534
# transforme a sharpness
# transforme a tensor  535
# transforme a sharpness
# transforme a tensor  536
# transforme a sharpness
# transforme a tensor  537
# transforme a sharpness
# transforme a tensor  538
# transforme a sharpness
# transforme a tensor  539
# transforme a sharpness
# transforme a tensor  540
# transforme a sharpness
# transforme a tensor  541
# transforme a sharpness
# transforme a tensor  542
# transforme a sharpness
# transforme a tensor  543
# transforme a sharpness
# transforme a tensor  544
# transforme a sharpness
# transforme a tensor  545
# transforme a sharpness
# transforme a tensor  546
# transforme a sharpness
# transforme a tensor  547
# transforme a sharpness
# transforme a tensor  548
# transforme a sharpness
# transforme a tensor  549
# transforme a sharpness
# transforme a tensor  550
# transforme a sharpness
# transforme a tensor  551
# transforme a sharpness
# transforme a tensor  552
# transforme a sharpness
# transforme a tensor  553
# transforme a sharpness
# transforme a tensor  554
# transforme a sharpness
# transforme a tensor  555
# transforme a sharpness
# transforme a tensor  556
# transforme a sharpness
# transforme a tensor  557
# transforme a sharpness
# transforme a tensor  558
# transforme a sharpness
# transforme a tensor  559
# transforme a sharpness
# transforme a tensor  560
# transforme a sharpness
# transforme a tensor  561
# transforme a sharpness
# transforme a tensor  562
# transforme a sharpness
# transforme a tensor  563
# transforme a sharpness
# transforme a tensor  564
# transforme a sharpness
# transforme a tensor  565
# transforme a sharpness
# transforme a tensor  566
# transforme a sharpness
# transforme a tensor  567
# transforme a sharpness
# transforme a tensor  568
# transforme a sharpness
# transforme a tensor  569
# transforme a sharpness
# transforme a tensor  570
# transforme a sharpness
# transforme a tensor  571
# transforme a sharpness
# transforme a tensor  572
# transforme a sharpness
# transforme a tensor  573
# transforme a sharpness
# transforme a tensor  574
# transforme a sharpness
# transforme a tensor  575
# transforme a sharpness
# transforme a tensor  576
# transforme a sharpness
# transforme a tensor  577
# transforme a sharpness
# transforme a tensor  578
# transforme a sharpness
# transforme a tensor  579
# transforme a sharpness
# transforme a tensor  580
# transforme a sharpness
# transforme a tensor  581
# transforme a sharpness
# transforme a tensor  582
# transforme a sharpness
# transforme a tensor  583
# transforme a sharpness
# transforme a tensor  584
# transforme a sharpness
# transforme a tensor  585
# transforme a sharpness
# transforme a tensor  586
# transforme a sharpness
# transforme a tensor  587
# transforme a sharpness
# transforme a tensor  588
# transforme a sharpness
# transforme a tensor  589
# transforme a sharpness
# transforme a tensor  590
# transforme a sharpness
# transforme a tensor  591
# transforme a sharpness
# transforme a tensor  592
# transforme a sharpness
# transforme a tensor  593
# transforme a sharpness
# transforme a tensor  594
# transforme a sharpness
# transforme a tensor  595
# transforme a sharpness
# transforme a tensor  596
# transforme a sharpness
# transforme a tensor  597
# transforme a sharpness
# transforme a tensor  598
# transforme a sharpness
# transforme a tensor  599
# transforme a sharpness
# transforme a tensor  600
# transforme a sharpness
# transforme a tensor  601
# transforme a sharpness
# transforme a tensor  602
# transforme a sharpness
# transforme a tensor  603
# transforme a sharpness
# transforme a tensor  604
# transforme a sharpness
# transforme a tensor  605
# transforme a sharpness
# transforme a tensor  606
# transforme a sharpness
# transforme a tensor  607
# transforme a sharpness
# transforme a tensor  608
# transforme a sharpness
# transforme a tensor  609
# transforme a sharpness
# transforme a tensor  610
# transforme a sharpness
# transforme a tensor  611
# transforme a sharpness
# transforme a tensor  612
# transforme a sharpness
# transforme a tensor  613
# transforme a sharpness
# transforme a tensor  614
# transforme a sharpness
# transforme a tensor  615
# transforme a sharpness
# transforme a tensor  616
# transforme a sharpness
# transforme a tensor  617
# transforme a sharpness
# transforme a tensor  618
# transforme a sharpness
# transforme a tensor  619
# transforme a sharpness
# transforme a tensor  620
# transforme a sharpness
# transforme a tensor  621
# transforme a sharpness
# transforme a tensor  622
# transforme a sharpness
# transforme a tensor  623
# transforme a sharpness
# transforme a tensor  624
# transforme a sharpness
# transforme a tensor  625
# transforme a sharpness
# transforme a tensor  626
# transforme a sharpness
# transforme a tensor  627
# transforme a sharpness
# transforme a tensor  628
# transforme a sharpness
# transforme a tensor  629
# transforme a sharpness
# transforme a tensor  630
# transforme a sharpness
# transforme a tensor  631
# transforme a sharpness
# transforme a tensor  632
# transforme a sharpness
# transforme a tensor  633
# transforme a sharpness
# transforme a tensor  634
# transforme a sharpness
# transforme a tensor  635
# transforme a sharpness
# transforme a tensor  636
# transforme a sharpness
# transforme a tensor  637
# transforme a sharpness
# transforme a tensor  638
# transforme a sharpness
# transforme a tensor  639
# transforme a sharpness
# transforme a tensor  640
# transforme a sharpness
# transforme a tensor  641
# transforme a sharpness
# transforme a tensor  642
# transforme a sharpness
# transforme a tensor  643
# transforme a sharpness
# transforme a tensor  644
# transforme a sharpness
# transforme a tensor  645
# transforme a sharpness
# transforme a tensor  646
# transforme a sharpness
# transforme a tensor  647
# transforme a sharpness
# transforme a tensor  648
# transforme a sharpness
# transforme a tensor  649
# transforme a sharpness
# transforme a tensor  650
# transforme a sharpness
# transforme a tensor  651
# transforme a sharpness
# transforme a tensor  652
# transforme a sharpness
# transforme a tensor  653
# transforme a sharpness
# transforme a tensor  654
# transforme a sharpness
# transforme a tensor  655
# transforme a sharpness
# transforme a tensor  656
# transforme a sharpness
# transforme a tensor  657
# transforme a sharpness
# transforme a tensor  658
# transforme a sharpness
# transforme a tensor  659
# transforme a sharpness
# transforme a tensor  660
# transforme a sharpness
# transforme a tensor  661
# transforme a sharpness
# transforme a tensor  662
# transforme a sharpness
# transforme a tensor  663
# transforme a sharpness
# transforme a tensor  664
# transforme a sharpness
# transforme a tensor  665
# transforme a sharpness
# transforme a tensor  666
# transforme a sharpness
# transforme a tensor  667
# transforme a sharpness
# transforme a tensor  668
# transforme a sharpness
# transforme a tensor  669
# transforme a sharpness
# transforme a tensor  670
# transforme a sharpness
# transforme a tensor  671
# transforme a sharpness
# transforme a tensor  672
# transforme a sharpness
# transforme a tensor  673
# transforme a sharpness
# transforme a tensor  674
# transforme a sharpness
# transforme a tensor  675
# transforme a sharpness
# transforme a tensor  676
# transforme a sharpness
# transforme a tensor  677
# transforme a sharpness
# transforme a tensor  678
# transforme a sharpness
# transforme a tensor  679
# transforme a sharpness
# transforme a tensor  680
# transforme a sharpness
# transforme a tensor  681
# transforme a sharpness
# transforme a tensor  682
# transforme a sharpness
# transforme a tensor  683
# transforme a sharpness
# transforme a tensor  684
# transforme a sharpness
# transforme a tensor  685
# transforme a sharpness
# transforme a tensor  686
# transforme a sharpness
# transforme a tensor  687
# transforme a sharpness
# transforme a tensor  688
# transforme a sharpness
# transforme a tensor  689
# transforme a sharpness
# transforme a tensor  690
# transforme a sharpness
# transforme a tensor  691
# transforme a sharpness
# transforme a tensor  692
# transforme a sharpness
# transforme a tensor  693
# transforme a sharpness
# transforme a tensor  694
# transforme a sharpness
# transforme a tensor  695
# transforme a sharpness
# transforme a tensor  696
# transforme a sharpness
# transforme a tensor  697
# transforme a sharpness
# transforme a tensor  698
# transforme a sharpness
# transforme a tensor  699
# transforme a sharpness
# transforme a tensor  700
# transforme a sharpness
# transforme a tensor  701
# transforme a sharpness
# transforme a tensor  702
# transforme a sharpness
# transforme a tensor  703
# transforme a sharpness
# transforme a tensor  704
# transforme a sharpness
# transforme a tensor  705
# transforme a sharpness
# transforme a tensor  706
# transforme a sharpness
# transforme a tensor  707
# transforme a sharpness
# transforme a tensor  708
# transforme a sharpness
# transforme a tensor  709
# transforme a sharpness
# transforme a tensor  710
# transforme a sharpness
# transforme a tensor  711
# transforme a sharpness
# transforme a tensor  712
# transforme a sharpness
# transforme a tensor  713
# transforme a sharpness
# transforme a tensor  714
# transforme a sharpness
# transforme a tensor  715
# transforme a sharpness
# transforme a tensor  716
# transforme a sharpness
# transforme a tensor  717
# transforme a sharpness
# transforme a tensor  718
# transforme a sharpness
# transforme a tensor  719
# transforme a sharpness
# transforme a tensor  720
# transforme a sharpness
# transforme a tensor  721
# transforme a sharpness
# transforme a tensor  722
# transforme a sharpness
# transforme a tensor  723
# transforme a sharpness
# transforme a tensor  724
# transforme a sharpness
# transforme a tensor  725
# transforme a sharpness
# transforme a tensor  726
# transforme a sharpness
# transforme a tensor  727
# transforme a sharpness
# transforme a tensor  728
# transforme a sharpness
# transforme a tensor  729
# transforme a sharpness
# transforme a tensor  730
# transforme a sharpness
# transforme a tensor  731
# transforme a sharpness
# transforme a tensor  732
# transforme a sharpness
# transforme a tensor  733
# transforme a sharpness
# transforme a tensor  734
# transforme a sharpness
# transforme a tensor  735
# transforme a sharpness
# transforme a tensor  736
# transforme a sharpness
# transforme a tensor  737
# transforme a sharpness
# transforme a tensor  738
# transforme a sharpness
# transforme a tensor  739
# transforme a sharpness
# transforme a tensor  740
# transforme a sharpness
# transforme a tensor  741
# transforme a sharpness
# transforme a tensor  742
# transforme a sharpness
# transforme a tensor  743
# transforme a sharpness
# transforme a tensor  744
# transforme a sharpness
# transforme a tensor  745
# transforme a sharpness
# transforme a tensor  746
# transforme a sharpness
# transforme a tensor  747
# transforme a sharpness
# transforme a tensor  748
# transforme a sharpness
# transforme a tensor  749
# transforme a sharpness
# transforme a tensor  750
# transforme a sharpness
# transforme a tensor  751
# transforme a sharpness
# transforme a tensor  752
# transforme a sharpness
# transforme a tensor  753
# transforme a sharpness
# transforme a tensor  754
# transforme a sharpness
# transforme a tensor  755
# transforme a sharpness
# transforme a tensor  756
# transforme a sharpness
# transforme a tensor  757
# transforme a sharpness
# transforme a tensor  758
# transforme a sharpness
# transforme a tensor  759
# transforme a sharpness
# transforme a tensor  760
# transforme a sharpness
# transforme a tensor  761
# transforme a sharpness
# transforme a tensor  762
# transforme a sharpness
# transforme a tensor  763
# transforme a sharpness
# transforme a tensor  764
# transforme a sharpness
# transforme a tensor  765
# transforme a sharpness
# transforme a tensor  766
# transforme a sharpness
# transforme a tensor  767
# transforme a sharpness
# transforme a tensor  768
# transforme a sharpness
# transforme a tensor  769
# transforme a sharpness
# transforme a tensor  770
# transforme a sharpness
# transforme a tensor  771
# transforme a sharpness
# transforme a tensor  772
# transforme a sharpness
# transforme a tensor  773
# transforme a sharpness
# transforme a tensor  774
# transforme a sharpness
# transforme a tensor  775
# transforme a sharpness
# transforme a tensor  776
# transforme a sharpness
# transforme a tensor  777
# transforme a sharpness
# transforme a tensor  778
# transforme a sharpness
# transforme a tensor  779
# transforme a sharpness
# transforme a tensor  780
# transforme a sharpness
# transforme a tensor  781
# transforme a sharpness
# transforme a tensor  782
# transforme a sharpness
# transforme a tensor  783
# transforme a sharpness
# transforme a tensor  784
# transforme a sharpness
# transforme a tensor  785
# transforme a sharpness
# transforme a tensor  786
# transforme a sharpness
# transforme a tensor  787
# transforme a sharpness
# transforme a tensor  788
# transforme a sharpness
# transforme a tensor  789
# transforme a sharpness
# transforme a tensor  790
# transforme a sharpness
# transforme a tensor  791
# transforme a sharpness
# transforme a tensor  792
# transforme a sharpness
# transforme a tensor  793
# transforme a sharpness
# transforme a tensor  794
# transforme a sharpness
# transforme a tensor  795
# transforme a sharpness
# transforme a tensor  796
# transforme a sharpness
# transforme a tensor  797
# transforme a sharpness
# transforme a tensor  798
# transforme a sharpness
# transforme a tensor  799
# transforme a sharpness
# transforme a tensor  800
# transforme a sharpness
# transforme a tensor  801
# transforme a sharpness
# transforme a tensor  802
# transforme a sharpness
# transforme a tensor  803
# transforme a sharpness
# transforme a tensor  804
# transforme a sharpness
# transforme a tensor  805
# transforme a sharpness
# transforme a tensor  806
# transforme a sharpness
# transforme a tensor  807
# transforme a sharpness
# transforme a tensor  808
# transforme a sharpness
# transforme a tensor  809
# transforme a sharpness
# transforme a tensor  810
# transforme a sharpness
# transforme a tensor  811
# transforme a sharpness
# transforme a tensor  812
# transforme a sharpness
# transforme a tensor  813
# transforme a sharpness
# transforme a tensor  814
# transforme a sharpness
# transforme a tensor  815
# transforme a sharpness
# transforme a tensor  816
# transforme a sharpness
# transforme a tensor  817
# transforme a sharpness
# transforme a tensor  818
# transforme a sharpness
# transforme a tensor  819
# transforme a sharpness
# transforme a tensor  820
# transforme a sharpness
# transforme a tensor  821
# transforme a sharpness
# transforme a tensor  822
# transforme a sharpness
# transforme a tensor  823
# transforme a sharpness
# transforme a tensor  824
# transforme a sharpness
# transforme a tensor  825
# transforme a sharpness
# transforme a tensor  826
# transforme a sharpness
# transforme a tensor  827
# transforme a sharpness
# transforme a tensor  828
# transforme a sharpness
# transforme a tensor  829
# transforme a sharpness
# transforme a tensor  830
# transforme a sharpness
# transforme a tensor  831
# transforme a sharpness
# transforme a tensor  832
# transforme a sharpness
# transforme a tensor  833
# transforme a sharpness
# transforme a tensor  834
# transforme a sharpness
# transforme a tensor  835
# transforme a sharpness
# transforme a tensor  836
# transforme a sharpness
# transforme a tensor  837
# transforme a sharpness
# transforme a tensor  838
# transforme a sharpness
# transforme a tensor  839
# transforme a sharpness
# transforme a tensor  840
# transforme a sharpness
# transforme a tensor  841
# transforme a sharpness
# transforme a tensor  842
# transforme a sharpness
# transforme a tensor  843
# transforme a sharpness
# transforme a tensor  844
# transforme a sharpness
# transforme a tensor  845
# transforme a sharpness
# transforme a tensor  846
# transforme a sharpness
# transforme a tensor  847
# transforme a sharpness
# transforme a tensor  848
# transforme a sharpness
# transforme a tensor  849
# transforme a sharpness
# transforme a tensor  850
# transforme a sharpness
# transforme a tensor  851
# transforme a sharpness
# transforme a tensor  852
# transforme a sharpness
# transforme a tensor  853
# transforme a sharpness
# transforme a tensor  854
# transforme a sharpness
# transforme a tensor  855
# transforme a sharpness
# transforme a tensor  856
# transforme a sharpness
# transforme a tensor  857
# transforme a sharpness
# transforme a tensor  858
# transforme a sharpness
# transforme a tensor  859
# transforme a sharpness
# transforme a tensor  860
# transforme a sharpness
# transforme a tensor  861
# transforme a sharpness
# transforme a tensor  862
# transforme a sharpness
# transforme a tensor  863
# transforme a sharpness
# transforme a tensor  864
# transforme a sharpness
# transforme a tensor  865
# transforme a sharpness
# transforme a tensor  866
# transforme a sharpness
# transforme a tensor  867
# transforme a sharpness
# transforme a tensor  868
# transforme a sharpness
# transforme a tensor  869
# transforme a sharpness
# transforme a tensor  870
# transforme a sharpness
# transforme a tensor  871
# transforme a sharpness
# transforme a tensor  872
# transforme a sharpness
# transforme a tensor  873
# transforme a sharpness
# transforme a tensor  874
# transforme a sharpness
# transforme a tensor  875
# transforme a sharpness
# transforme a tensor  876
# transforme a sharpness
# transforme a tensor  877
# transforme a sharpness
# transforme a tensor  878
# transforme a sharpness
# transforme a tensor  879
# transforme a sharpness
# transforme a tensor  880
# transforme a sharpness
# transforme a tensor  881
# transforme a sharpness
# transforme a tensor  882
# transforme a sharpness
# transforme a tensor  883
# transforme a sharpness
# transforme a tensor  884
# transforme a sharpness
# transforme a tensor  885
# transforme a sharpness
# transforme a tensor  886
# transforme a sharpness
# transforme a tensor  887
# transforme a sharpness
# transforme a tensor  888
# transforme a sharpness
# transforme a tensor  889
# transforme a sharpness
# transforme a tensor  890
# transforme a sharpness
# transforme a tensor  891
# transforme a sharpness
# transforme a tensor  892
# transforme a sharpness
# transforme a tensor  893
# transforme a sharpness
# transforme a tensor  894
# transforme a sharpness
# transforme a tensor  895
# transforme a sharpness
# transforme a tensor  896
# transforme a sharpness
# transforme a tensor  897
# transforme a sharpness
# transforme a tensor  898
# transforme a sharpness
# transforme a tensor  899
# transforme a sharpness
# transforme a tensor  900
# transforme a sharpness
# transforme a tensor  901
# transforme a sharpness
# transforme a tensor  902
# transforme a sharpness
# transforme a tensor  903
# transforme a sharpness
# transforme a tensor  904
# transforme a sharpness
# transforme a tensor  905
# transforme a sharpness
# transforme a tensor  906
# transforme a sharpness
# transforme a tensor  907
# transforme a sharpness
# transforme a tensor  908
# transforme a sharpness
# transforme a tensor  909
# transforme a sharpness
# transforme a tensor  910
# transforme a sharpness
# transforme a tensor  911
# transforme a sharpness
# transforme a tensor  912
# transforme a sharpness
# transforme a tensor  913
# transforme a sharpness
# transforme a tensor  914
# transforme a sharpness
# transforme a tensor  915
# transforme a sharpness
# transforme a tensor  916
# transforme a sharpness
# transforme a tensor  917
# transforme a sharpness
# transforme a tensor  918
# transforme a sharpness
# transforme a tensor  919
# transforme a sharpness
# transforme a tensor  920
# transforme a sharpness
# transforme a tensor  921
# transforme a sharpness
# transforme a tensor  922
# transforme a sharpness
# transforme a tensor  923
# transforme a sharpness
# transforme a tensor  924
# transforme a sharpness
# transforme a tensor  925
# transforme a sharpness
# transforme a tensor  926
# transforme a sharpness
# transforme a tensor  927
# transforme a sharpness
# transforme a tensor  928
# transforme a sharpness
# transforme a tensor  929
# transforme a sharpness
# transforme a tensor  930
# transforme a sharpness
# transforme a tensor  931
# transforme a sharpness
# transforme a tensor  932
# transforme a sharpness
# transforme a tensor  933
# transforme a sharpness
# transforme a tensor  934
# transforme a sharpness
# transforme a tensor  935
# transforme a sharpness
# transforme a tensor  936
# transforme a sharpness
# transforme a tensor  937
# transforme a sharpness
# transforme a tensor  938
# transforme a sharpness
# transforme a tensor  939
# transforme a sharpness
# transforme a tensor  940
# transforme a sharpness
# transforme a tensor  941
# transforme a sharpness
# transforme a tensor  942
# transforme a sharpness
# transforme a tensor  943
# transforme a sharpness
# transforme a tensor  944
# transforme a sharpness
# transforme a tensor  945
# transforme a sharpness
# transforme a tensor  946
# transforme a sharpness
# transforme a tensor  947
# transforme a sharpness
# transforme a tensor  948
# transforme a sharpness
# transforme a tensor  949
# transforme a sharpness
# transforme a tensor  950
# transforme a sharpness
# transforme a tensor  951
# transforme a sharpness
# transforme a tensor  952
# transforme a sharpness
# transforme a tensor  953
# transforme a sharpness
# transforme a tensor  954
# transforme a sharpness
# transforme a tensor  955
# transforme a sharpness
# transforme a tensor  956
# transforme a sharpness
# transforme a tensor  957
# transforme a sharpness
# transforme a tensor  958
# transforme a sharpness
# transforme a tensor  959
# transforme a sharpness
# transforme a tensor  960
# transforme a sharpness
# transforme a tensor  961
# transforme a sharpness
# transforme a tensor  962
# transforme a sharpness
# transforme a tensor  963
# transforme a sharpness
# transforme a tensor  964
# transforme a sharpness
# transforme a tensor  965
# transforme a sharpness
# transforme a tensor  966
# transforme a sharpness
# transforme a tensor  967
# transforme a sharpness
# transforme a tensor  968
# transforme a sharpness
# transforme a tensor  969
# transforme a sharpness
# transforme a tensor  970
# transforme a sharpness
# transforme a tensor  971
# transforme a sharpness
# transforme a tensor  972
# transforme a sharpness
# transforme a tensor  973
# transforme a sharpness
# transforme a tensor  974
# transforme a sharpness
# transforme a tensor  975
# transforme a sharpness
# transforme a tensor  976
# transforme a sharpness
# transforme a tensor  977
# transforme a sharpness
# transforme a tensor  978
# transforme a sharpness
# transforme a tensor  979
# transforme a sharpness
# transforme a tensor  980
# transforme a sharpness
# transforme a tensor  981
# transforme a sharpness
# transforme a tensor  982
# transforme a sharpness
# transforme a tensor  983
# transforme a sharpness
# transforme a tensor  984
# transforme a sharpness
# transforme a tensor  985
# transforme a sharpness
# transforme a tensor  986
# transforme a sharpness
# transforme a tensor  987
# transforme a sharpness
# transforme a tensor  988
# transforme a sharpness
# transforme a tensor  989
# transforme a sharpness
# transforme a tensor  990
# transforme a sharpness
# transforme a tensor  991
# transforme a sharpness
# transforme a tensor  992
# transforme a sharpness
# transforme a tensor  993
# transforme a sharpness
# transforme a tensor  994
# transforme a sharpness
# transforme a tensor  995
# transforme a sharpness
# transforme a tensor  996
# transforme a sharpness
# transforme a tensor  997
# transforme a sharpness
# transforme a tensor  998
# transforme a sharpness
# transforme a tensor  999
# transforme a sharpness
# transforme a tensor  1000
# transforme a sharpness
# transforme a tensor  1001
# transforme a sharpness
# transforme a tensor  1002
# transforme a sharpness
# transforme a tensor  1003
# transforme a sharpness
# transforme a tensor  1004
# transforme a sharpness
# transforme a tensor  1005
# transforme a sharpness
# transforme a tensor  1006
# transforme a sharpness
# transforme a tensor  1007
# transforme a sharpness
# transforme a tensor  1008
# transforme a sharpness
# transforme a tensor  1009
# transforme a sharpness
# transforme a tensor  1010
# transforme a sharpness
# transforme a tensor  1011
# transforme a sharpness
# transforme a tensor  1012
# transforme a sharpness
# transforme a tensor  1013
# transforme a sharpness
# transforme a tensor  1014
# transforme a sharpness
# transforme a tensor  1015
# transforme a sharpness
# transforme a tensor  1016
# transforme a sharpness
# transforme a tensor  1017
# transforme a sharpness
# transforme a tensor  1018
# transforme a sharpness
# transforme a tensor  1019
# transforme a sharpness
# transforme a tensor  1020
# transforme a sharpness
# transforme a tensor  1021
# transforme a sharpness
# transforme a tensor  1022
# transforme a sharpness
# transforme a tensor  1023
# transforme a sharpness
# transforme a tensor  1024
# transforme a sharpness
# transforme a tensor  1025
# transforme a sharpness

# %%
import torch.optim as optim

# Create an optimizer
optimizer = optim.Adam(new_model.parameters(), lr=lr)


n_samples = len(train_data2)
n_classes = 4

w1 = 5
w2 = n_samples/(n_classes*52)
w3 = 2
w4 = n_samples/(n_classes*172)

weight = torch.tensor([w1,w2,w3,w4])

weight = weight.to(device)

# Loss Function
criterion = nn.NLLLoss(weight= weight)

# %% [markdown]
# # Entrenamiento

# %% [markdown]
# * Creamos la clase Early stopping para evitar el overfitting

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, trace_func=print): #path='checkpoint.pt', ):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        # self.path = path
        self.trace_func = trace_func
        self.best_model = None

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        # torch.save(model.state_dict(), self.path)
        self.best_model = model
        self.val_loss_min = val_loss

# %%
import sys
from progress.bar import Bar

def train_model(new_model, train_data, criterion, optimizer, num_epochs, patience):

    train_losses = []
    # to track the validation loss as the model trains
    valid_losses = []
    # to track the average validation loss per epoch as the model trains
    avg_valid_losses = [] 
    # to track the average training loss per epoch as the model trains
    avg_train_losses = []
    
    # initialize the early_stopping object
    early_stopping = EarlyStopping(patience=patience, verbose=True)


    Bar.check_tty = False
    Bar.file = sys.stdout
    

    for epoch in range(num_epochs):

        total_loss = 0.0
        processed = 0
        bar = Bar('Training Model', max=len(dataloader))

        new_model.train()        
        for index, data_dict in enumerate(dataloader):
            input_tensor = data_dict["input"]
            gt_tensor = data_dict["target"]

            input_tensor = input_tensor.to(device)
            gt_tensor = gt_tensor.to(device)

            optimizer.zero_grad()
            output = new_model(input_tensor)
            loss = criterion(output, gt_tensor)
            train_losses.append(loss.item())
            total_loss += loss.item()

            loss.backward()
            optimizer.step()
            processed += input_tensor.shape[0]
            Bar.suffix = 'Train: [{0}][{1}/{2}]|Tot: {total:} |ETA: {eta:} '.format(epoch+1, processed, len(train_data),total=bar.elapsed_td, eta=bar.eta_td)
            Bar.suffix = Bar.suffix + '| Loss {:.4f} '.format(total_loss / (index + 1))
            bar.next()
        bar.finish()


        # validate the model #
        ######################
        new_model.eval() # prep model for evaluation
        for index, data_dict in enumerate(dataloader_val):

            val_tensor = data_dict["input"]
            gtv_tensor = data_dict["target"]

            val_tensor = val_tensor.to(device)
            gtv_tensor = gtv_tensor.to(device)

            # forward pass: compute predicted outputs by passing inputs to the model
            output = new_model(val_tensor)
            # calculate the loss
            loss = criterion(output, gtv_tensor)
            # record validation loss
            valid_losses.append(loss.item())

        # print training/validation statistics 
        # calculate average loss over an epoch
        train_loss = np.average(train_losses)
        valid_loss = np.average(valid_losses)
        avg_valid_losses.append(valid_loss)
        avg_train_losses.append(train_loss)
        
        epoch_len = len(str(num_epochs))
        
        print_msg = (f'[{epoch:>{epoch_len}}/{num_epochs:>{epoch_len}}] ' +
                 f'valid_loss: {valid_loss:.5f}')
        
        print(print_msg)
        
        # clear lists to track next epoch
        train_losses = []
        valid_losses = []
        
        # early_stopping needs the validation loss to check if it has decresed, 
        # and if it has, it will make a checkpoint of the current model
        early_stopping(valid_loss, new_model)
        
        if early_stopping.early_stop:
          print("Early stopping")
          break
        
    # load the last checkpoint with the best model
    # new_model.load_state_dict(torch.load('checkpoint.pt'))

    return  new_model, avg_train_losses, avg_valid_losses, early_stopping.best_model

    # return new_model

# %%
# patience = 20
model,train_loss, val_loss, best_model = train_model(new_model, train_data2, criterion, optimizer, num_epochs = 25, patience = 20)
# Out:
# Training Model |################################| Train: [1][4096/4096]|Tot: 0:00:43 |ETA: 0:00:01 | Loss 1.3049
# [ 0/25] valid_loss: 1.20317
# Validation loss decreased (inf --> 1.203173).  Saving model ...
# Training Model |################################| Train: [2][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 1.1797
# [ 1/25] valid_loss: 0.95951
# Validation loss decreased (1.203173 --> 0.959515).  Saving model ...
# Training Model |################################| Train: [3][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 1.0559
# [ 2/25] valid_loss: 0.83767
# Validation loss decreased (0.959515 --> 0.837666).  Saving model ...
# Training Model |################################| Train: [4][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.9294
# [ 3/25] valid_loss: 0.80195
# Validation loss decreased (0.837666 --> 0.801946).  Saving model ...
# Training Model |################################| Train: [5][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.7994
# [ 4/25] valid_loss: 0.65650
# Validation loss decreased (0.801946 --> 0.656499).  Saving model ...
# Training Model |################################| Train: [6][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.6862
# [ 5/25] valid_loss: 0.53175
# Validation loss decreased (0.656499 --> 0.531754).  Saving model ...
# Training Model |################################| Train: [7][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.6301
# [ 6/25] valid_loss: 0.51198
# Validation loss decreased (0.531754 --> 0.511983).  Saving model ...
# Training Model |################################| Train: [8][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.5716
# [ 7/25] valid_loss: 0.65326
# EarlyStopping counter: 1 out of 20
# Training Model |################################| Train: [9][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.5787
# [ 8/25] valid_loss: 0.37386
# Validation loss decreased (0.511983 --> 0.373865).  Saving model ...
# Training Model |################################| Train: [10][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4920
# [ 9/25] valid_loss: 0.28693
# Validation loss decreased (0.373865 --> 0.286928).  Saving model ...
# Training Model |################################| Train: [11][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4377
# [10/25] valid_loss: 0.25308
# Validation loss decreased (0.286928 --> 0.253076).  Saving model ...
# Training Model |################################| Train: [12][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4329
# [11/25] valid_loss: 0.26624
# EarlyStopping counter: 1 out of 20
# Training Model |################################| Train: [13][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4307
# [12/25] valid_loss: 0.20829
# Validation loss decreased (0.253076 --> 0.208286).  Saving model ...
# Training Model |################################| Train: [14][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4247
# [13/25] valid_loss: 0.24806
# EarlyStopping counter: 1 out of 20
# Training Model |################################| Train: [15][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4047
# [14/25] valid_loss: 0.23972
# EarlyStopping counter: 2 out of 20
# Training Model |################################| Train: [16][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4045
# [15/25] valid_loss: 0.23341
# EarlyStopping counter: 3 out of 20
# Training Model |################################| Train: [17][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4517
# [16/25] valid_loss: 0.38521
# EarlyStopping counter: 4 out of 20
# Training Model |################################| Train: [18][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4425
# [17/25] valid_loss: 0.32345
# EarlyStopping counter: 5 out of 20
# Training Model |################################| Train: [19][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4470
# [18/25] valid_loss: 0.36308
# EarlyStopping counter: 6 out of 20
# Training Model |################################| Train: [20][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.3973
# [19/25] valid_loss: 0.21402
# EarlyStopping counter: 7 out of 20
# Training Model |################################| Train: [21][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.3633
# [20/25] valid_loss: 0.17843
# Validation loss decreased (0.208286 --> 0.178430).  Saving model ...
# Training Model |################################| Train: [22][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.3600
# [21/25] valid_loss: 0.15258
# Validation loss decreased (0.178430 --> 0.152582).  Saving model ...
# Training Model |################################| Train: [23][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4068
# [22/25] valid_loss: 0.27549
# EarlyStopping counter: 1 out of 20
# Training Model |################################| Train: [24][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.4427
# [23/25] valid_loss: 0.20825
# EarlyStopping counter: 2 out of 20
# Training Model |################################| Train: [25][4096/4096]|Tot: 0:00:42 |ETA: 0:00:01 | Loss 0.3664
# [24/25] valid_loss: 0.18673
# EarlyStopping counter: 3 out of 20

# %% [markdown]
# Habría que probar de agregar un Early stopping para controlar el overfitting

# %%
# visualize the loss as the network trained
fig = plt.figure(figsize=(10,8))
plt.plot(range(1,len(train_loss)+1),train_loss, label='Training Loss')
plt.plot(range(1,len(val_loss)+1),val_loss,label='Validation Loss')

# find position of lowest validation loss
minposs = val_loss.index(min(val_loss))+1 
plt.axvline(minposs, linestyle='--', color='r',label='Early Stopping Checkpoint')

plt.xlabel('epochs')
plt.ylabel('loss')
plt.ylim(0, 2) # consistent scale
plt.xlim(0, len(train_loss)+1) # consistent scale
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
fig.savefig('loss_plot.png', bbox_inches='tight')

# %% [markdown]
# Podemos ver que la función de val_loss siempre es menor que la de train_loss, aunque las curvas muestran ciertas irregularidades lo que nos podría indicar que ambos conjuntos no son representativos, se necesitaría aumentar el tamaño del dataset. Esto nos proporcionaría más información para la clasificación de las imágenes en las 4 clases y podríamos llegar a ver a qué número de épocas se llega la estabilidad de las curvas.

# %% [markdown]
# # Pre procesamos datos nuevos

# %%
transfor = transforms.RandomAutocontrast()

def preprocess(path_to_image, label):
    img = cv2.imread(path_to_image)
    img = cv2.resize(img, input_size)    
    img = img / 255.
    input_tensor = torch.from_numpy(img).reshape(1, 3, input_size[0],input_size[1]).float()
    input_tensor = transfor(input_tensor)
    gt_tensor = torch.tensor([label])
    return input_tensor, gt_tensor

# %%
y_true = []
y_pred = []

def test_model(new_model, test_data):
    new_model = new_model.eval()
    Bar.check_tty = False
    Bar.file = sys.stdout
    bar = Bar('Testing Model', max=len(test_data))

    stats = [0 for _ in categories]
    total_items = [0 for _ in categories]
    for index, input_data in enumerate(test_data):
        img_path, target_class = input_data

        input_tensor, _ = preprocess(img_path, target_class)
        input_tensor = input_tensor.to(device)
        output = new_model(input_tensor)
        prediction = torch.argmax(output).item()

        y_pred.append(prediction)
        y_true.append(target_class)

        if target_class == prediction:
            stats[target_class] += 1
        total_items[target_class] += 1
        Bar.suffix = 'Test: [{0}/{1}]|Tot: {total:} |ETA: {eta:} '.format(index, len(test_data),total=bar.elapsed_td, eta=bar.eta_td)
        bar.next()
    
    bar.finish()
    for category_name, stat, tot in zip(categories, stats, total_items):
        acc = stat * 1.0 / tot
        print("Accuracy for class {}: {:.4f}".format(category_name, acc))

    print("\nReporte de clasificación: \n", classification_report(y_true, y_pred, target_names= categories))
    print("\nMatriz de confusión: \n")

    conf_arr = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

    ax = sns.heatmap(conf_arr, cmap='Greens', annot=True, fmt='d', xticklabels=categories, yticklabels=categories)

    plt.title('Alzheimer\'s Disease Diagnosis')
    plt.xlabel('Prediction')
    plt.ylabel('Truth')
    plt.show(ax)

    print("\n Balanced accuracy score: ", balanced_accuracy_score(y_true, y_pred))
    print("\n F1 score for unbalanced classes: ", f1_score(y_true, y_pred, average='macro'), "\n")

# %% [markdown]
# # Probamos el modelo con datos nuevos

# %%
test_model(best_model, train_data)
test_model(best_model, test_data)
# Out:
# Testing Model |################################| Test: [5120/5121]|Tot: 0:01:07 |ETA: 0:00:01
# Accuracy for class MildDemented: 0.9679
# Accuracy for class ModerateDemented: 0.9615
# Accuracy for class NonDemented: 0.9852
# Accuracy for class VeryMildDemented: 0.9978
#
# Reporte de clasificación:
#                    precision    recall  f1-score   support
#
#     MildDemented       0.99      0.97      0.98       717
# ModerateDemented       1.00      0.96      0.98        52
#      NonDemented       0.99      0.99      0.99      2560
# VeryMildDemented       0.98      1.00      0.99      1792
#
#         accuracy                           0.99      5121
#        macro avg       0.99      0.98      0.98      5121
#     weighted avg       0.99      0.99      0.99      5121
#
#
# Matriz de confusión:
#  Balanced accuracy score:  0.9780961163683771
#
#  F1 score for unbalanced classes:  0.9834980795786579
#
# Testing Model |################################| Test: [1278/1279]|Tot: 0:07:36 |ETA: 0:00:01
# Accuracy for class MildDemented: 0.3408
# Accuracy for class ModerateDemented: 0.0000
# Accuracy for class NonDemented: 0.7188
# Accuracy for class VeryMildDemented: 0.6004
#
# Reporte de clasificación:
#                    precision    recall  f1-score   support
#
#     MildDemented       0.91      0.84      0.87       896
# ModerateDemented       1.00      0.78      0.88        64
#      NonDemented       0.93      0.93      0.93      3200
# VeryMildDemented       0.89      0.92      0.90      2240
#
#         accuracy                           0.91      6400
#        macro avg       0.93      0.87      0.90      6400
#     weighted avg       0.91      0.91      0.91      6400
#
#
# Matriz de confusión:
#  Balanced accuracy score:  0.868515625
#
#  F1 score for unbalanced classes:  0.8965947487273052

# %% [markdown]
# # Aumentación de datos

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2019/12/image-augmentation-deep-learning-pytorch/
#
# https://medium.com/analytics-vidhya/image-data-augmentation-to-balance-dataset-in-classification-tasks-5e25bbd9a228
